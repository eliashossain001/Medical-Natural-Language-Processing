# %% [markdown]
# # **Mount the Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Import required modules**

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import warnings 
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# # **Dataset loading**

# %%
# Load dataset
def load_data():
    data =pd.read_csv("/content/drive/MyDrive/Research Work/NLP Dataset/Medical NER Dataset/mtsamples.csv")
    return data

# %%
NER_df = load_data()
NER_df.head()
# Out:
#    Unnamed: 0                                        description  \
# 0           0   A 23-year-old white female presents with comp...
# 1           1           Consult for laparoscopic gastric bypass.
# 2           2           Consult for laparoscopic gastric bypass.
# 3           3                             2-D M-Mode. Doppler.
# 4           4                                 2-D Echocardiogram
#
#              medical_specialty                                sample_name  \
# 0         Allergy / Immunology                         Allergic Rhinitis
# 1                   Bariatrics   Laparoscopic Gastric Bypass Consult - 2
# 2                   Bariatrics   Laparoscopic Gastric Bypass Consult - 1
# 3   Cardiovascular / Pulmonary                    2-D Echocardiogram - 1
# 4   Cardiovascular / Pulmonary                    2-D Echocardiogram - 2
#
#                                        transcription  \
# 0  SUBJECTIVE:,  This 23-year-old white female pr...
# 1  PAST MEDICAL HISTORY:, He has difficulty climb...
# 2  HISTORY OF PRESENT ILLNESS: , I have seen ABC ...
# 3  2-D M-MODE: , ,1.  Left atrial enlargement wit...
# 4  1.  The left ventricular cavity size and wall ...
#
#                                             keywords
# 0  allergy / immunology, allergic rhinitis, aller...
# 1  bariatrics, laparoscopic gastric bypass, weigh...
# 2  bariatrics, laparoscopic gastric bypass, heart...
# 3  cardiovascular / pulmonary, 2-d m-mode, dopple...
# 4  cardiovascular / pulmonary, 2-d, doppler, echo...

# %% [markdown]
# Observation: As you have seen that there is an unnecessary columns like 'Unnamed' which is not required and seems to be redundant one, so it has to be eliminated. Let's do that

# %%
NER_df.drop('Unnamed: 0',inplace=True,axis = 1)

# %%
NER_df.head(3)
# Out:
#                                          description      medical_specialty  \
# 0   A 23-year-old white female presents with comp...   Allergy / Immunology
# 1           Consult for laparoscopic gastric bypass.             Bariatrics
# 2           Consult for laparoscopic gastric bypass.             Bariatrics
#
#                                  sample_name  \
# 0                         Allergic Rhinitis
# 1   Laparoscopic Gastric Bypass Consult - 2
# 2   Laparoscopic Gastric Bypass Consult - 1
#
#                                        transcription  \
# 0  SUBJECTIVE:,  This 23-year-old white female pr...
# 1  PAST MEDICAL HISTORY:, He has difficulty climb...
# 2  HISTORY OF PRESENT ILLNESS: , I have seen ABC ...
#
#                                             keywords
# 0  allergy / immunology, allergic rhinitis, aller...
# 1  bariatrics, laparoscopic gastric bypass, weigh...
# 2  bariatrics, laparoscopic gastric bypass, heart...

# %% [markdown]
# I'm gonna remove two attributes, e.g., sample_name and transcription because I do not know the hypothesis of those columns, however, it can be added later, at this moment, I'm focusing to work on other columns

# %%
NER_df.drop(['medical_specialty', 'sample_name'], axis=1, inplace= True)

# %%
NER_df.head(5)
# Out:
#                                          description  \
# 0   A 23-year-old white female presents with comp...
# 1           Consult for laparoscopic gastric bypass.
# 2           Consult for laparoscopic gastric bypass.
# 3                             2-D M-Mode. Doppler.
# 4                                 2-D Echocardiogram
#
#                                        transcription  \
# 0  SUBJECTIVE:,  This 23-year-old white female pr...
# 1  PAST MEDICAL HISTORY:, He has difficulty climb...
# 2  HISTORY OF PRESENT ILLNESS: , I have seen ABC ...
# 3  2-D M-MODE: , ,1.  Left atrial enlargement wit...
# 4  1.  The left ventricular cavity size and wall ...
#
#                                             keywords
# 0  allergy / immunology, allergic rhinitis, aller...
# 1  bariatrics, laparoscopic gastric bypass, weigh...
# 2  bariatrics, laparoscopic gastric bypass, heart...
# 3  cardiovascular / pulmonary, 2-d m-mode, dopple...
# 4  cardiovascular / pulmonary, 2-d, doppler, echo...

# %% [markdown]
# ## **Text Preprocessing Layer**

# %% [markdown]
# Preprocessing the text is significant steps for the case of natural language processing because data often collect from various online repositories so that it is containing many noise and outliers. In order to make a clean corpus, these have to be filtered out properly. However, the following procedures will be applied for removing the missing values and making a clean corpus. I have considered the following steps for dealing with the unstructured text data. These steps are recommended by the researchers even though there might have another methods. <br>

# %% [markdown]
# **Step 1 :** Handelling null and missing values <br>
# **Step 2 :** Converting html entities <br>
# **Step 3 :** Removing "@user" from all the desriptions <br>
# **Step 4 :**Changing all the text into lowercase <br>
# **Step 5 :** Apostrophe Lookup <br>
# **Step 6 :**Short Word Lookup <br>
# **Step 7 :** Emoticon Lookup <br>
# **Step 8 :** Replacing Special Characters with space <br>
# **Step 9 :**Replacing Numbers (integers) with space <br>
# **Step 10 :**Removing words whom length is 1 <br>
# **Step 11 :**Removing URL from the text (if exists) <br>
# **Step 12 :**Spelling correction <br>
# **Step 13 :** Remove stopwords + Tokenization  <br>
# **Step 14 :** Text normalization: Lammetization and stemming <br>
# **Step 15 :**Part-of-speech tagging (POS tagging) <br>
# **Step 16 :** Biomedical Name Entity Recognition (BIO_NER) <br>
# **Step 17 :** Abbreviation detection <br>

# %% [markdown]
# **Step 1 : Handelling null and missing values**

# %%
NER_df.isnull().sum()
# Out:
# description         0
# transcription      33
# keywords         1068
# dtype: int64

# %%
NER_df = NER_df.dropna(how='any',axis=0)

# %%
NER_df.isnull().sum()
# Out:
# description      0
# transcription    0
# keywords         0
# dtype: int64

# %% [markdown]
# **Step 2 : Converting html entities**

# %%
# Importing HTMLParser
from html.parser import HTMLParser
html_parser = HTMLParser()

# %%
# Created a new columns i.e. clean_tweet contains the same tweets but cleaned version
NER_df['clean_desc'] = NER_df['description'].apply(lambda x: html_parser.unescape(x))
NER_df.tail(10)
# Out:
#                                             description  \
# 4977   Gentleman with long-standing morbid obesity, ...
# 4978   Preop evaluation regarding gastric bypass sur...
# 4979   Patient scheduled for laparoscopic gastric by...
# 4980   Evaluation for elective surgical weight loss ...
# 4982                  Evaluation for bariatric surgery.
# 4984   Patient suffered from morbid obesity for many...
# 4985   Patient presented to the Bariatric Surgery Se...
# 4989   Evaluation for elective surgical weight loss ...
# 4993   Chronic glossitis, xerostomia, probable envir...
# 4995   This is a 14-month-old baby boy Caucasian who...
#
#                                           transcription  \
# 4977  HISTORY OF PRESENT ILLNESS: , In short, the pa...
# 4978  REASON FOR VISIT:,  Preop evaluation regarding...
# 4979  HISTORY: , The patient is scheduled for laparo...
# 4980  PAST MEDICAL HISTORY: , She has a history of h...
# 4982  PAST MEDICAL HISTORY: , Her medical conditions...
# 4984  ADMISSION DIAGNOSIS:,  Morbid obesity.  BMI is...
# 4985  HISTORY OF PRESENT ILLNESS:,  Ms. A is a 55-ye...
# 4989  PAST MEDICAL HISTORY:  ,She had a negative str...
# 4993  HISTORY:,  A 55-year-old female presents self-...
# 4995  ADMITTING DIAGNOSIS: , Kawasaki disease.,DISCH...
#
#                                                keywords  \
# 4977  bariatrics, medifast, medifast dieting, hypert...
# 4978  bariatrics, medifast, medifast diet, preop eva...
# 4979  bariatrics, medifast, laparoscopic gastric byp...
# 4980  bariatrics, elective surgical weight loss, sur...
# 4982  bariatrics, evaluation for bariatric surgery, ...
# 4984  bariatrics, laparoscopic gastric bypass, gastr...
# 4985  bariatrics, jenny craig, medifast, nutrisystem...
# 4989  bariatrics, elective surgical weight loss, sur...
# 4993  allergy / immunology, chronic glossitis, xeros...
# 4995  allergy / immunology, mucous membranes, conjun...
#
#                                              clean_desc
# 4977   Gentleman with long-standing morbid obesity, ...
# 4978   Preop evaluation regarding gastric bypass sur...
# 4979   Patient scheduled for laparoscopic gastric by...
# 4980   Evaluation for elective surgical weight loss ...
# 4982                  Evaluation for bariatric surgery.
# 4984   Patient suffered from morbid obesity for many...
# 4985   Patient presented to the Bariatric Surgery Se...
# 4989   Evaluation for elective surgical weight loss ...
# 4993   Chronic glossitis, xerostomia, probable envir...
# 4995   This is a 14-month-old baby boy Caucasian who...

# %% [markdown]
# **Remove HTML taggs**

# %%
import re

# %%
def remove_html(text):
    html_pattern = re.compile('<.*?>')
    return html_pattern.sub(r'', text)

text = """<div>
<h1> H2O</h1>
<p> AutoML</p>
<a href="https://www.h2o.ai/products/h2o-driverless-ai/"> Driverless AI</a>
</div>"""

print(remove_html(text))
# Out:
#  H2O
#  AutoML
#  Driverless AI

# %%
NER_df['clean_desc'] = NER_df['description'].apply(lambda x: remove_html(x))
NER_df.head(10)
# Out:
#                                          description  \
# 0   A 23-year-old white female presents with comp...
# 1           Consult for laparoscopic gastric bypass.
# 2           Consult for laparoscopic gastric bypass.
# 3                             2-D M-Mode. Doppler.
# 4                                 2-D Echocardiogram
# 5   Morbid obesity.  Laparoscopic antecolic anteg...
# 6   Liposuction of the supraumbilical abdomen, re...
# 7                                 2-D Echocardiogram
# 8   Suction-assisted lipectomy - lipodystrophy of...
# 9                         Echocardiogram and Doppler
#
#                                        transcription  \
# 0  SUBJECTIVE:,  This 23-year-old white female pr...
# 1  PAST MEDICAL HISTORY:, He has difficulty climb...
# 2  HISTORY OF PRESENT ILLNESS: , I have seen ABC ...
# 3  2-D M-MODE: , ,1.  Left atrial enlargement wit...
# 4  1.  The left ventricular cavity size and wall ...
# 5  PREOPERATIVE DIAGNOSIS: , Morbid obesity.,POST...
# 6  PREOPERATIVE DIAGNOSES:,1.  Deformity, right b...
# 7  2-D ECHOCARDIOGRAM,Multiple views of the heart...
# 8  PREOPERATIVE DIAGNOSIS: , Lipodystrophy of the...
# 9  DESCRIPTION:,1.  Normal cardiac chambers size....
#
#                                             keywords  \
# 0  allergy / immunology, allergic rhinitis, aller...
# 1  bariatrics, laparoscopic gastric bypass, weigh...
# 2  bariatrics, laparoscopic gastric bypass, heart...
# 3  cardiovascular / pulmonary, 2-d m-mode, dopple...
# 4  cardiovascular / pulmonary, 2-d, doppler, echo...
# 5  bariatrics, gastric bypass, eea anastomosis, r...
# 6  bariatrics, breast reconstruction, excess, lma...
# 7  cardiovascular / pulmonary, 2-d echocardiogram...
# 8  bariatrics, lipodystrophy, abd pads, suction-a...
# 9  cardiovascular / pulmonary, ejection fraction,...
#
#                                           clean_desc
# 0   A 23-year-old white female presents with comp...
# 1           Consult for laparoscopic gastric bypass.
# 2           Consult for laparoscopic gastric bypass.
# 3                             2-D M-Mode. Doppler.
# 4                                 2-D Echocardiogram
# 5   Morbid obesity.  Laparoscopic antecolic anteg...
# 6   Liposuction of the supraumbilical abdomen, re...
# 7                                 2-D Echocardiogram
# 8   Suction-assisted lipectomy - lipodystrophy of...
# 9                         Echocardiogram and Doppler

# %% [markdown]
# **STEP 3: Removing "@user" from all the text (if exists)**

# %%
def remove_pattern(input_txt, pattern):
    r = re.findall(pattern, input_txt)
    for i in r:
        input_txt = re.sub(i, '', input_txt)
    return input_txt

# %%
NER_df['clean_desc'] = np.vectorize(remove_pattern)(NER_df['clean_desc'], "@[\w]*")
NER_df.tail(10)
# Out:
#                                             description  \
# 4977   Gentleman with long-standing morbid obesity, ...
# 4978   Preop evaluation regarding gastric bypass sur...
# 4979   Patient scheduled for laparoscopic gastric by...
# 4980   Evaluation for elective surgical weight loss ...
# 4982                  Evaluation for bariatric surgery.
# 4984   Patient suffered from morbid obesity for many...
# 4985   Patient presented to the Bariatric Surgery Se...
# 4989   Evaluation for elective surgical weight loss ...
# 4993   Chronic glossitis, xerostomia, probable envir...
# 4995   This is a 14-month-old baby boy Caucasian who...
#
#                                           transcription  \
# 4977  HISTORY OF PRESENT ILLNESS: , In short, the pa...
# 4978  REASON FOR VISIT:,  Preop evaluation regarding...
# 4979  HISTORY: , The patient is scheduled for laparo...
# 4980  PAST MEDICAL HISTORY: , She has a history of h...
# 4982  PAST MEDICAL HISTORY: , Her medical conditions...
# 4984  ADMISSION DIAGNOSIS:,  Morbid obesity.  BMI is...
# 4985  HISTORY OF PRESENT ILLNESS:,  Ms. A is a 55-ye...
# 4989  PAST MEDICAL HISTORY:  ,She had a negative str...
# 4993  HISTORY:,  A 55-year-old female presents self-...
# 4995  ADMITTING DIAGNOSIS: , Kawasaki disease.,DISCH...
#
#                                                keywords  \
# 4977  bariatrics, medifast, medifast dieting, hypert...
# 4978  bariatrics, medifast, medifast diet, preop eva...
# 4979  bariatrics, medifast, laparoscopic gastric byp...
# 4980  bariatrics, elective surgical weight loss, sur...
# 4982  bariatrics, evaluation for bariatric surgery, ...
# 4984  bariatrics, laparoscopic gastric bypass, gastr...
# 4985  bariatrics, jenny craig, medifast, nutrisystem...
# 4989  bariatrics, elective surgical weight loss, sur...
# 4993  allergy / immunology, chronic glossitis, xeros...
# 4995  allergy / immunology, mucous membranes, conjun...
#
#                                              clean_desc
# 4977   Gentleman with long-standing morbid obesity, ...
# 4978   Preop evaluation regarding gastric bypass sur...
# 4979   Patient scheduled for laparoscopic gastric by...
# 4980   Evaluation for elective surgical weight loss ...
# 4982                  Evaluation for bariatric surgery.
# 4984   Patient suffered from morbid obesity for many...
# 4985   Patient presented to the Bariatric Surgery Se...
# 4989   Evaluation for elective surgical weight loss ...
# 4993   Chronic glossitis, xerostomia, probable envir...
# 4995   This is a 14-month-old baby boy Caucasian who...

# %% [markdown]
# **STEP 4 : Changing all the text into lowercase**

# %%
NER_df['clean_desc'] = NER_df['clean_desc'].apply(lambda x: x.lower())
NER_df.head(10)
# Out:
#                                          description  \
# 0   A 23-year-old white female presents with comp...
# 1           Consult for laparoscopic gastric bypass.
# 2           Consult for laparoscopic gastric bypass.
# 3                             2-D M-Mode. Doppler.
# 4                                 2-D Echocardiogram
# 5   Morbid obesity.  Laparoscopic antecolic anteg...
# 6   Liposuction of the supraumbilical abdomen, re...
# 7                                 2-D Echocardiogram
# 8   Suction-assisted lipectomy - lipodystrophy of...
# 9                         Echocardiogram and Doppler
#
#                                        transcription  \
# 0  SUBJECTIVE:,  This 23-year-old white female pr...
# 1  PAST MEDICAL HISTORY:, He has difficulty climb...
# 2  HISTORY OF PRESENT ILLNESS: , I have seen ABC ...
# 3  2-D M-MODE: , ,1.  Left atrial enlargement wit...
# 4  1.  The left ventricular cavity size and wall ...
# 5  PREOPERATIVE DIAGNOSIS: , Morbid obesity.,POST...
# 6  PREOPERATIVE DIAGNOSES:,1.  Deformity, right b...
# 7  2-D ECHOCARDIOGRAM,Multiple views of the heart...
# 8  PREOPERATIVE DIAGNOSIS: , Lipodystrophy of the...
# 9  DESCRIPTION:,1.  Normal cardiac chambers size....
#
#                                             keywords  \
# 0  allergy / immunology, allergic rhinitis, aller...
# 1  bariatrics, laparoscopic gastric bypass, weigh...
# 2  bariatrics, laparoscopic gastric bypass, heart...
# 3  cardiovascular / pulmonary, 2-d m-mode, dopple...
# 4  cardiovascular / pulmonary, 2-d, doppler, echo...
# 5  bariatrics, gastric bypass, eea anastomosis, r...
# 6  bariatrics, breast reconstruction, excess, lma...
# 7  cardiovascular / pulmonary, 2-d echocardiogram...
# 8  bariatrics, lipodystrophy, abd pads, suction-a...
# 9  cardiovascular / pulmonary, ejection fraction,...
#
#                                           clean_desc
# 0   a 23-year-old white female presents with comp...
# 1           consult for laparoscopic gastric bypass.
# 2           consult for laparoscopic gastric bypass.
# 3                             2-d m-mode. doppler.
# 4                                 2-d echocardiogram
# 5   morbid obesity.  laparoscopic antecolic anteg...
# 6   liposuction of the supraumbilical abdomen, re...
# 7                                 2-d echocardiogram
# 8   suction-assisted lipectomy - lipodystrophy of...
# 9                         echocardiogram and doppler

# %% [markdown]
# **STEP 5 : Apostrophe Lookup**

# %%
# Apostrophe Dictionary
apostrophe_dict = {
"ain't": "am not / are not",
"aren't": "are not / am not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he had / he would",
"he'd've": "he would have",
"he'll": "he shall / he will",
"he'll've": "he shall have / he will have",
"he's": "he has / he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how has / how is",
"i'd": "I had / I would",
"i'd've": "I would have",
"i'll": "I shall / I will",
"i'll've": "I shall have / I will have",
"i'm": "I am",
"i've": "I have",
"isn't": "is not",
"it'd": "it had / it would",
"it'd've": "it would have",
"it'll": "it shall / it will",
"it'll've": "it shall have / it will have",
"it's": "it has / it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she had / she would",
"she'd've": "she would have",
"she'll": "she shall / she will",
"she'll've": "she shall have / she will have",
"she's": "she has / she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so as / so is",
"that'd": "that would / that had",
"that'd've": "that would have",
"that's": "that has / that is",
"there'd": "there had / there would",
"there'd've": "there would have",
"there's": "there has / there is",
"they'd": "they had / they would",
"they'd've": "they would have",
"they'll": "they shall / they will",
"they'll've": "they shall have / they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we had / we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what shall / what will",
"what'll've": "what shall have / what will have",
"what're": "what are",
"what's": "what has / what is",
"what've": "what have",
"when's": "when has / when is",
"when've": "when have",
"where'd": "where did",
"where's": "where has / where is",
"where've": "where have",
"who'll": "who shall / who will",
"who'll've": "who shall have / who will have",
"who's": "who has / who is",
"who've": "who have",
"why's": "why has / why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you had / you would",
"you'd've": "you would have",
"you'll": "you shall / you will",
"you'll've": "you shall have / you will have",
"you're": "you are",
"you've": "you have"
}

# %%
def lookup_dict(text, dictionary):
    for word in text.split():
        if word.lower() in dictionary:
            if word.lower() in text.split():
                text = text.replace(word, dictionary[word.lower()])
    return text

# %%
NER_df['clean_desc'] = NER_df['clean_desc'].apply(lambda x: lookup_dict(x,apostrophe_dict))
NER_df.head(10)
# Out:
#                                          description  \
# 0   A 23-year-old white female presents with comp...
# 1           Consult for laparoscopic gastric bypass.
# 2           Consult for laparoscopic gastric bypass.
# 3                             2-D M-Mode. Doppler.
# 4                                 2-D Echocardiogram
# 5   Morbid obesity.  Laparoscopic antecolic anteg...
# 6   Liposuction of the supraumbilical abdomen, re...
# 7                                 2-D Echocardiogram
# 8   Suction-assisted lipectomy - lipodystrophy of...
# 9                         Echocardiogram and Doppler
#
#                                        transcription  \
# 0  SUBJECTIVE:,  This 23-year-old white female pr...
# 1  PAST MEDICAL HISTORY:, He has difficulty climb...
# 2  HISTORY OF PRESENT ILLNESS: , I have seen ABC ...
# 3  2-D M-MODE: , ,1.  Left atrial enlargement wit...
# 4  1.  The left ventricular cavity size and wall ...
# 5  PREOPERATIVE DIAGNOSIS: , Morbid obesity.,POST...
# 6  PREOPERATIVE DIAGNOSES:,1.  Deformity, right b...
# 7  2-D ECHOCARDIOGRAM,Multiple views of the heart...
# 8  PREOPERATIVE DIAGNOSIS: , Lipodystrophy of the...
# 9  DESCRIPTION:,1.  Normal cardiac chambers size....
#
#                                             keywords  \
# 0  allergy / immunology, allergic rhinitis, aller...
# 1  bariatrics, laparoscopic gastric bypass, weigh...
# 2  bariatrics, laparoscopic gastric bypass, heart...
# 3  cardiovascular / pulmonary, 2-d m-mode, dopple...
# 4  cardiovascular / pulmonary, 2-d, doppler, echo...
# 5  bariatrics, gastric bypass, eea anastomosis, r...
# 6  bariatrics, breast reconstruction, excess, lma...
# 7  cardiovascular / pulmonary, 2-d echocardiogram...
# 8  bariatrics, lipodystrophy, abd pads, suction-a...
# 9  cardiovascular / pulmonary, ejection fraction,...
#
#                                           clean_desc
# 0   a 23-year-old white female presents with comp...
# 1           consult for laparoscopic gastric bypass.
# 2           consult for laparoscopic gastric bypass.
# 3                             2-d m-mode. doppler.
# 4                                 2-d echocardiogram
# 5   morbid obesity.  laparoscopic antecolic anteg...
# 6   liposuction of the supraumbilical abdomen, re...
# 7                                 2-d echocardiogram
# 8   suction-assisted lipectomy - lipodystrophy of...
# 9                         echocardiogram and doppler

# %% [markdown]
# **STEP 6 : Short Word Lookup**

# %%
short_word_dict = {
"121": "one to one",
"a/s/l": "age, sex, location",
"adn": "any day now",
"afaik": "as far as I know",
"afk": "away from keyboard",
"aight": "alright",
"alol": "actually laughing out loud",
"b4": "before",
"b4n": "bye for now",
"bak": "back at the keyboard",
"bf": "boyfriend",
"bff": "best friends forever",
"bfn": "bye for now",
"bg": "big grin",
"bta": "but then again",
"btw": "by the way",
"cid": "crying in disgrace",
"cnp": "continued in my next post",
"cp": "chat post",
"cu": "see you",
"cul": "see you later",
"cul8r": "see you later",
"cya": "bye",
"cyo": "see you online",
"dbau": "doing business as usual",
"fud": "fear, uncertainty, and doubt",
"fwiw": "for what it's worth",
"fyi": "for your information",
"g": "grin",
"g2g": "got to go",
"ga": "go ahead",
"gal": "get a life",
"gf": "girlfriend",
"gfn": "gone for now",
"gmbo": "giggling my butt off",
"gmta": "great minds think alike",
"h8": "hate",
"hagn": "have a good night",
"hdop": "help delete online predators",
"hhis": "hanging head in shame",
"iac": "in any case",
"ianal": "I am not a lawyer",
"ic": "I see",
"idk": "I don't know",
"imao": "in my arrogant opinion",
"imnsho": "in my not so humble opinion",
"imo": "in my opinion",
"iow": "in other words",
"ipn": "I’m posting naked",
"irl": "in real life",
"jk": "just kidding",
"l8r": "later",
"ld": "later, dude",
"ldr": "long distance relationship",
"llta": "lots and lots of thunderous applause",
"lmao": "laugh my ass off",
"lmirl": "let's meet in real life",
"lol": "laugh out loud",
"ltr": "longterm relationship",
"lulab": "love you like a brother",
"lulas": "love you like a sister",
"luv": "love",
"m/f": "male or female",
"m8": "mate",
"milf": "mother I would like to fuck",
"oll": "online love",
"omg": "oh my god",
"otoh": "on the other hand",
"pir": "parent in room",
"ppl": "people",
"r": "are",
"rofl": "roll on the floor laughing",
"rpg": "role playing games",
"ru": "are you",
"shid": "slaps head in disgust",
"somy": "sick of me yet",
"sot": "short of time",
"thanx": "thanks",
"thx": "thanks",
"ttyl": "talk to you later",
"u": "you",
"ur": "you are",
"uw": "you’re welcome",
"wb": "welcome back",
"wfm": "works for me",
"wibni": "wouldn't it be nice if",
"wtf": "what the fuck",
"wtg": "way to go",
"wtgp": "want to go private",
"ym": "young man",
"gr8": "great"
}

# %%
NER_df['clean_desc'] = NER_df['clean_desc'].apply(lambda x: lookup_dict(x,short_word_dict))
NER_df.head(10)
# Out:
#                                          description  \
# 0   A 23-year-old white female presents with comp...
# 1           Consult for laparoscopic gastric bypass.
# 2           Consult for laparoscopic gastric bypass.
# 3                             2-D M-Mode. Doppler.
# 4                                 2-D Echocardiogram
# 5   Morbid obesity.  Laparoscopic antecolic anteg...
# 6   Liposuction of the supraumbilical abdomen, re...
# 7                                 2-D Echocardiogram
# 8   Suction-assisted lipectomy - lipodystrophy of...
# 9                         Echocardiogram and Doppler
#
#                                        transcription  \
# 0  SUBJECTIVE:,  This 23-year-old white female pr...
# 1  PAST MEDICAL HISTORY:, He has difficulty climb...
# 2  HISTORY OF PRESENT ILLNESS: , I have seen ABC ...
# 3  2-D M-MODE: , ,1.  Left atrial enlargement wit...
# 4  1.  The left ventricular cavity size and wall ...
# 5  PREOPERATIVE DIAGNOSIS: , Morbid obesity.,POST...
# 6  PREOPERATIVE DIAGNOSES:,1.  Deformity, right b...
# 7  2-D ECHOCARDIOGRAM,Multiple views of the heart...
# 8  PREOPERATIVE DIAGNOSIS: , Lipodystrophy of the...
# 9  DESCRIPTION:,1.  Normal cardiac chambers size....
#
#                                             keywords  \
# 0  allergy / immunology, allergic rhinitis, aller...
# 1  bariatrics, laparoscopic gastric bypass, weigh...
# 2  bariatrics, laparoscopic gastric bypass, heart...
# 3  cardiovascular / pulmonary, 2-d m-mode, dopple...
# 4  cardiovascular / pulmonary, 2-d, doppler, echo...
# 5  bariatrics, gastric bypass, eea anastomosis, r...
# 6  bariatrics, breast reconstruction, excess, lma...
# 7  cardiovascular / pulmonary, 2-d echocardiogram...
# 8  bariatrics, lipodystrophy, abd pads, suction-a...
# 9  cardiovascular / pulmonary, ejection fraction,...
#
#                                           clean_desc
# 0   a 23-year-old white female presents with comp...
# 1           consult for laparoscopic gastric bypass.
# 2           consult for laparoscopic gastric bypass.
# 3                             2-d m-mode. doppler.
# 4                                 2-d echocardiogram
# 5   morbid obesity.  laparoscopic antecolic anteg...
# 6   liposuction of the supraumbilical abdomen, re...
# 7                                 2-d echocardiogram
# 8   suction-assisted lipectomy - lipodystrophy of...
# 9                         echocardiogram and doppler

# %% [markdown]
# **STEP 7 : Emoticon Lookup**

# %%
emoticon_dict = {
":)": "happy",
":‑)": "happy",
":-]": "happy",
":-3": "happy",
":->": "happy",
"8-)": "happy",
":-}": "happy",
":o)": "happy",
":c)": "happy",
":^)": "happy",
"=]": "happy",
"=)": "happy",
"<3": "happy",
":-(": "sad",
":(": "sad",
":c": "sad",
":<": "sad",
":[": "sad",
">:[": "sad",
":{": "sad",
">:(": "sad",
":-c": "sad",
":-< ": "sad",
":-[": "sad",
":-||": "sad"
}

# %%
emoticon_dict
# Out:
# {'8-)': 'happy',
#  ':(': 'sad',
#  ':)': 'happy',
#  ':-(': 'sad',
#  ':-3': 'happy',
#  ':-< ': 'sad',
#  ':->': 'happy',
#  ':-[': 'sad',
#  ':-]': 'happy',
#  ':-c': 'sad',
#  ':-||': 'sad',
#  ':-}': 'happy',
#  ':<': 'sad',
#  ':[': 'sad',
#  ':^)': 'happy',
#  ':c': 'sad',
#  ':c)': 'happy',
#  ':o)': 'happy',
#  ':{': 'sad',
#  ':‑)': 'happy',
#  '<3': 'happy',
#  '=)': 'happy',
#  '=]': 'happy',
#  '>:(': 'sad',
#  '>:[': 'sad'}

# %%
NER_df['clean_desc'] = NER_df['clean_desc'].apply(lambda x: lookup_dict(x,emoticon_dict))
NER_df.head(10)
# Out:
#                                          description  \
# 0   A 23-year-old white female presents with comp...
# 1           Consult for laparoscopic gastric bypass.
# 2           Consult for laparoscopic gastric bypass.
# 3                             2-D M-Mode. Doppler.
# 4                                 2-D Echocardiogram
# 5   Morbid obesity.  Laparoscopic antecolic anteg...
# 6   Liposuction of the supraumbilical abdomen, re...
# 7                                 2-D Echocardiogram
# 8   Suction-assisted lipectomy - lipodystrophy of...
# 9                         Echocardiogram and Doppler
#
#                                        transcription  \
# 0  SUBJECTIVE:,  This 23-year-old white female pr...
# 1  PAST MEDICAL HISTORY:, He has difficulty climb...
# 2  HISTORY OF PRESENT ILLNESS: , I have seen ABC ...
# 3  2-D M-MODE: , ,1.  Left atrial enlargement wit...
# 4  1.  The left ventricular cavity size and wall ...
# 5  PREOPERATIVE DIAGNOSIS: , Morbid obesity.,POST...
# 6  PREOPERATIVE DIAGNOSES:,1.  Deformity, right b...
# 7  2-D ECHOCARDIOGRAM,Multiple views of the heart...
# 8  PREOPERATIVE DIAGNOSIS: , Lipodystrophy of the...
# 9  DESCRIPTION:,1.  Normal cardiac chambers size....
#
#                                             keywords  \
# 0  allergy / immunology, allergic rhinitis, aller...
# 1  bariatrics, laparoscopic gastric bypass, weigh...
# 2  bariatrics, laparoscopic gastric bypass, heart...
# 3  cardiovascular / pulmonary, 2-d m-mode, dopple...
# 4  cardiovascular / pulmonary, 2-d, doppler, echo...
# 5  bariatrics, gastric bypass, eea anastomosis, r...
# 6  bariatrics, breast reconstruction, excess, lma...
# 7  cardiovascular / pulmonary, 2-d echocardiogram...
# 8  bariatrics, lipodystrophy, abd pads, suction-a...
# 9  cardiovascular / pulmonary, ejection fraction,...
#
#                                           clean_desc
# 0   a 23-year-old white female presents with comp...
# 1           consult for laparoscopic gastric bypass.
# 2           consult for laparoscopic gastric bypass.
# 3                             2-d m-mode. doppler.
# 4                                 2-d echocardiogram
# 5   morbid obesity.  laparoscopic antecolic anteg...
# 6   liposuction of the supraumbilical abdomen, re...
# 7                                 2-d echocardiogram
# 8   suction-assisted lipectomy - lipodystrophy of...
# 9                         echocardiogram and doppler

# %% [markdown]
# **STEP 7 : ReplacingPunctuations with space**

# %%
NER_df['clean_desc'] = NER_df['clean_desc'].apply(lambda x: re.sub(r'[^\w\s]',' ',x))
NER_df.head(10)
# Out:
#                                          description  \
# 0   A 23-year-old white female presents with comp...
# 1           Consult for laparoscopic gastric bypass.
# 2           Consult for laparoscopic gastric bypass.
# 3                             2-D M-Mode. Doppler.
# 4                                 2-D Echocardiogram
# 5   Morbid obesity.  Laparoscopic antecolic anteg...
# 6   Liposuction of the supraumbilical abdomen, re...
# 7                                 2-D Echocardiogram
# 8   Suction-assisted lipectomy - lipodystrophy of...
# 9                         Echocardiogram and Doppler
#
#                                        transcription  \
# 0  SUBJECTIVE:,  This 23-year-old white female pr...
# 1  PAST MEDICAL HISTORY:, He has difficulty climb...
# 2  HISTORY OF PRESENT ILLNESS: , I have seen ABC ...
# 3  2-D M-MODE: , ,1.  Left atrial enlargement wit...
# 4  1.  The left ventricular cavity size and wall ...
# 5  PREOPERATIVE DIAGNOSIS: , Morbid obesity.,POST...
# 6  PREOPERATIVE DIAGNOSES:,1.  Deformity, right b...
# 7  2-D ECHOCARDIOGRAM,Multiple views of the heart...
# 8  PREOPERATIVE DIAGNOSIS: , Lipodystrophy of the...
# 9  DESCRIPTION:,1.  Normal cardiac chambers size....
#
#                                             keywords  \
# 0  allergy / immunology, allergic rhinitis, aller...
# 1  bariatrics, laparoscopic gastric bypass, weigh...
# 2  bariatrics, laparoscopic gastric bypass, heart...
# 3  cardiovascular / pulmonary, 2-d m-mode, dopple...
# 4  cardiovascular / pulmonary, 2-d, doppler, echo...
# 5  bariatrics, gastric bypass, eea anastomosis, r...
# 6  bariatrics, breast reconstruction, excess, lma...
# 7  cardiovascular / pulmonary, 2-d echocardiogram...
# 8  bariatrics, lipodystrophy, abd pads, suction-a...
# 9  cardiovascular / pulmonary, ejection fraction,...
#
#                                           clean_desc
# 0   a 23 year old white female presents with comp...
# 1           consult for laparoscopic gastric bypass
# 2           consult for laparoscopic gastric bypass
# 3                             2 d m mode  doppler
# 4                                 2 d echocardiogram
# 5   morbid obesity   laparoscopic antecolic anteg...
# 6   liposuction of the supraumbilical abdomen  re...
# 7                                 2 d echocardiogram
# 8   suction assisted lipectomy   lipodystrophy of...
# 9                         echocardiogram and doppler

# %% [markdown]
# **STEP 8 : Replacing Special Characters with space**

# %%
NER_df['clean_desc'] = NER_df['clean_desc'].apply(lambda x: re.sub(r'[^a-zA-Z0-9]',' ',x))
NER_df.head(10)
# Out:
#                                          description  \
# 0   A 23-year-old white female presents with comp...
# 1           Consult for laparoscopic gastric bypass.
# 2           Consult for laparoscopic gastric bypass.
# 3                             2-D M-Mode. Doppler.
# 4                                 2-D Echocardiogram
# 5   Morbid obesity.  Laparoscopic antecolic anteg...
# 6   Liposuction of the supraumbilical abdomen, re...
# 7                                 2-D Echocardiogram
# 8   Suction-assisted lipectomy - lipodystrophy of...
# 9                         Echocardiogram and Doppler
#
#                                        transcription  \
# 0  SUBJECTIVE:,  This 23-year-old white female pr...
# 1  PAST MEDICAL HISTORY:, He has difficulty climb...
# 2  HISTORY OF PRESENT ILLNESS: , I have seen ABC ...
# 3  2-D M-MODE: , ,1.  Left atrial enlargement wit...
# 4  1.  The left ventricular cavity size and wall ...
# 5  PREOPERATIVE DIAGNOSIS: , Morbid obesity.,POST...
# 6  PREOPERATIVE DIAGNOSES:,1.  Deformity, right b...
# 7  2-D ECHOCARDIOGRAM,Multiple views of the heart...
# 8  PREOPERATIVE DIAGNOSIS: , Lipodystrophy of the...
# 9  DESCRIPTION:,1.  Normal cardiac chambers size....
#
#                                             keywords  \
# 0  allergy / immunology, allergic rhinitis, aller...
# 1  bariatrics, laparoscopic gastric bypass, weigh...
# 2  bariatrics, laparoscopic gastric bypass, heart...
# 3  cardiovascular / pulmonary, 2-d m-mode, dopple...
# 4  cardiovascular / pulmonary, 2-d, doppler, echo...
# 5  bariatrics, gastric bypass, eea anastomosis, r...
# 6  bariatrics, breast reconstruction, excess, lma...
# 7  cardiovascular / pulmonary, 2-d echocardiogram...
# 8  bariatrics, lipodystrophy, abd pads, suction-a...
# 9  cardiovascular / pulmonary, ejection fraction,...
#
#                                           clean_desc
# 0   a 23 year old white female presents with comp...
# 1           consult for laparoscopic gastric bypass
# 2           consult for laparoscopic gastric bypass
# 3                             2 d m mode  doppler
# 4                                 2 d echocardiogram
# 5   morbid obesity   laparoscopic antecolic anteg...
# 6   liposuction of the supraumbilical abdomen  re...
# 7                                 2 d echocardiogram
# 8   suction assisted lipectomy   lipodystrophy of...
# 9                         echocardiogram and doppler

# %% [markdown]
# **STEP 9 : Replacing Numbers (integers) with space**

# %%
NER_df['clean_desc'] = NER_df['clean_desc'].apply(lambda x: re.sub(r'[^a-zA-Z]',' ',x))
NER_df.head(10)
# Out:
#                                          description  \
# 0   A 23-year-old white female presents with comp...
# 1           Consult for laparoscopic gastric bypass.
# 2           Consult for laparoscopic gastric bypass.
# 3                             2-D M-Mode. Doppler.
# 4                                 2-D Echocardiogram
# 5   Morbid obesity.  Laparoscopic antecolic anteg...
# 6   Liposuction of the supraumbilical abdomen, re...
# 7                                 2-D Echocardiogram
# 8   Suction-assisted lipectomy - lipodystrophy of...
# 9                         Echocardiogram and Doppler
#
#                                        transcription  \
# 0  SUBJECTIVE:,  This 23-year-old white female pr...
# 1  PAST MEDICAL HISTORY:, He has difficulty climb...
# 2  HISTORY OF PRESENT ILLNESS: , I have seen ABC ...
# 3  2-D M-MODE: , ,1.  Left atrial enlargement wit...
# 4  1.  The left ventricular cavity size and wall ...
# 5  PREOPERATIVE DIAGNOSIS: , Morbid obesity.,POST...
# 6  PREOPERATIVE DIAGNOSES:,1.  Deformity, right b...
# 7  2-D ECHOCARDIOGRAM,Multiple views of the heart...
# 8  PREOPERATIVE DIAGNOSIS: , Lipodystrophy of the...
# 9  DESCRIPTION:,1.  Normal cardiac chambers size....
#
#                                             keywords  \
# 0  allergy / immunology, allergic rhinitis, aller...
# 1  bariatrics, laparoscopic gastric bypass, weigh...
# 2  bariatrics, laparoscopic gastric bypass, heart...
# 3  cardiovascular / pulmonary, 2-d m-mode, dopple...
# 4  cardiovascular / pulmonary, 2-d, doppler, echo...
# 5  bariatrics, gastric bypass, eea anastomosis, r...
# 6  bariatrics, breast reconstruction, excess, lma...
# 7  cardiovascular / pulmonary, 2-d echocardiogram...
# 8  bariatrics, lipodystrophy, abd pads, suction-a...
# 9  cardiovascular / pulmonary, ejection fraction,...
#
#                                           clean_desc
# 0   a    year old white female presents with comp...
# 1           consult for laparoscopic gastric bypass
# 2           consult for laparoscopic gastric bypass
# 3                               d m mode  doppler
# 4                                   d echocardiogram
# 5   morbid obesity   laparoscopic antecolic anteg...
# 6   liposuction of the supraumbilical abdomen  re...
# 7                                   d echocardiogram
# 8   suction assisted lipectomy   lipodystrophy of...
# 9                         echocardiogram and doppler

# %% [markdown]
# **STEP 10 : Removing words whom length is 1**

# %%
NER_df['clean_desc'] = NER_df['clean_desc'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>1]))
NER_df['clean_desc'][0:5]
# Out:
# 0    year old white female presents with complaint ...
# 1              consult for laparoscopic gastric bypass
# 2              consult for laparoscopic gastric bypass
# 3                                         mode doppler
# 4                                       echocardiogram
# Name: clean_desc, dtype: object

# %% [markdown]
# **STEP 11: Remove URL from Text**

# %%
import re
def remove_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub(r'', text)

# %%
NER_df['clean_desc'] = NER_df['clean_desc'].apply(lambda x: remove_urls(x))
NER_df.head(10)
# Out:
#                                          description  \
# 0   A 23-year-old white female presents with comp...
# 1           Consult for laparoscopic gastric bypass.
# 2           Consult for laparoscopic gastric bypass.
# 3                             2-D M-Mode. Doppler.
# 4                                 2-D Echocardiogram
# 5   Morbid obesity.  Laparoscopic antecolic anteg...
# 6   Liposuction of the supraumbilical abdomen, re...
# 7                                 2-D Echocardiogram
# 8   Suction-assisted lipectomy - lipodystrophy of...
# 9                         Echocardiogram and Doppler
#
#                                        transcription  \
# 0  SUBJECTIVE:,  This 23-year-old white female pr...
# 1  PAST MEDICAL HISTORY:, He has difficulty climb...
# 2  HISTORY OF PRESENT ILLNESS: , I have seen ABC ...
# 3  2-D M-MODE: , ,1.  Left atrial enlargement wit...
# 4  1.  The left ventricular cavity size and wall ...
# 5  PREOPERATIVE DIAGNOSIS: , Morbid obesity.,POST...
# 6  PREOPERATIVE DIAGNOSES:,1.  Deformity, right b...
# 7  2-D ECHOCARDIOGRAM,Multiple views of the heart...
# 8  PREOPERATIVE DIAGNOSIS: , Lipodystrophy of the...
# 9  DESCRIPTION:,1.  Normal cardiac chambers size....
#
#                                             keywords  \
# 0  allergy / immunology, allergic rhinitis, aller...
# 1  bariatrics, laparoscopic gastric bypass, weigh...
# 2  bariatrics, laparoscopic gastric bypass, heart...
# 3  cardiovascular / pulmonary, 2-d m-mode, dopple...
# 4  cardiovascular / pulmonary, 2-d, doppler, echo...
# 5  bariatrics, gastric bypass, eea anastomosis, r...
# 6  bariatrics, breast reconstruction, excess, lma...
# 7  cardiovascular / pulmonary, 2-d echocardiogram...
# 8  bariatrics, lipodystrophy, abd pads, suction-a...
# 9  cardiovascular / pulmonary, ejection fraction,...
#
#                                           clean_desc
# 0  year old white female presents with complaint ...
# 1            consult for laparoscopic gastric bypass
# 2            consult for laparoscopic gastric bypass
# 3                                       mode doppler
# 4                                     echocardiogram
# 5  morbid obesity laparoscopic antecolic antegast...
# 6  liposuction of the supraumbilical abdomen revi...
# 7                                     echocardiogram
# 8  suction assisted lipectomy lipodystrophy of th...
# 9                         echocardiogram and doppler

# %% [markdown]
# **STEP 12 : Spelling Correction - With TextBlob Library**

# %%
from textblob import TextBlob
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Spelling correction is a cool feature which TextBlob offers, we can be accessed using the correct function as shown below.
blob = TextBlob("Why are you stting on this bech??") # Scentence with two errors
print(blob.correct()) # Correct function give us the best possible word simmilar to "gret"
# Out:
# Why are you sitting on this bench??

# %%
# we can see all the similar matches our first error along with the probability score.
blob.words[3].spellcheck()
# Out:
# [('sitting', 0.8078078078078078),
#  ('setting', 0.11411411411411411),
#  ('string', 0.036036036036036036),
#  ('sting', 0.02702702702702703),
#  ('stating', 0.015015015015015015)]

# %%
# Not cleaning the just showing the spelling check as its take lot of time to process all these tweets
## Shown sample how its must done
text = NER_df['clean_desc'][0:10].apply(lambda x: str(TextBlob(x).correct()))
text
# Out:
# 0    year old white female presents with complaint ...
# 1                consult for laparoscopic gastric pass
# 2                consult for laparoscopic gastric pass
# 3                                          mode copper
# 4                                       echocardiogram
# 5    morbid obesity laparoscopic antecolic antegast...
# 6    liposuction of the supraumbilical abdomen revi...
# 7                                       echocardiogram
# 8    suction assisted lipectomy lipodystrophy of th...
# 9                            echocardiogram and copper
# Name: clean_desc, dtype: object

# %%
# Importing stop words from NLTK coupus and word tokenizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
# Creating token for the clean tweets
NER_df['NER_token'] = NER_df['clean_desc'].apply(lambda x: word_tokenize(x))
NER_df.head(10)
# Out:
#                                          description  \
# 0   A 23-year-old white female presents with comp...
# 1           Consult for laparoscopic gastric bypass.
# 2           Consult for laparoscopic gastric bypass.
# 3                             2-D M-Mode. Doppler.
# 4                                 2-D Echocardiogram
# 5   Morbid obesity.  Laparoscopic antecolic anteg...
# 6   Liposuction of the supraumbilical abdomen, re...
# 7                                 2-D Echocardiogram
# 8   Suction-assisted lipectomy - lipodystrophy of...
# 9                         Echocardiogram and Doppler
#
#                                        transcription  \
# 0  SUBJECTIVE:,  This 23-year-old white female pr...
# 1  PAST MEDICAL HISTORY:, He has difficulty climb...
# 2  HISTORY OF PRESENT ILLNESS: , I have seen ABC ...
# 3  2-D M-MODE: , ,1.  Left atrial enlargement wit...
# 4  1.  The left ventricular cavity size and wall ...
# 5  PREOPERATIVE DIAGNOSIS: , Morbid obesity.,POST...
# 6  PREOPERATIVE DIAGNOSES:,1.  Deformity, right b...
# 7  2-D ECHOCARDIOGRAM,Multiple views of the heart...
# 8  PREOPERATIVE DIAGNOSIS: , Lipodystrophy of the...
# 9  DESCRIPTION:,1.  Normal cardiac chambers size....
#
#                                             keywords  \
# 0  allergy / immunology, allergic rhinitis, aller...
# 1  bariatrics, laparoscopic gastric bypass, weigh...
# 2  bariatrics, laparoscopic gastric bypass, heart...
# 3  cardiovascular / pulmonary, 2-d m-mode, dopple...
# 4  cardiovascular / pulmonary, 2-d, doppler, echo...
# 5  bariatrics, gastric bypass, eea anastomosis, r...
# 6  bariatrics, breast reconstruction, excess, lma...
# 7  cardiovascular / pulmonary, 2-d echocardiogram...
# 8  bariatrics, lipodystrophy, abd pads, suction-a...
# 9  cardiovascular / pulmonary, ejection fraction,...
#
#                                           clean_desc  \
# 0  year old white female presents with complaint ...
# 1            consult for laparoscopic gastric bypass
# 2            consult for laparoscopic gastric bypass
# 3                                       mode doppler
# 4                                     echocardiogram
# 5  morbid obesity laparoscopic antecolic antegast...
# 6  liposuction of the supraumbilical abdomen revi...
# 7                                     echocardiogram
# 8  suction assisted lipectomy lipodystrophy of th...
# 9                         echocardiogram and doppler
#
#                                            NER_token
# 0  [year, old, white, female, presents, with, com...
# 1      [consult, for, laparoscopic, gastric, bypass]
# 2      [consult, for, laparoscopic, gastric, bypass]
# 3                                    [mode, doppler]
# 4                                   [echocardiogram]
# 5  [morbid, obesity, laparoscopic, antecolic, ant...
# 6  [liposuction, of, the, supraumbilical, abdomen...
# 7                                   [echocardiogram]
# 8  [suction, assisted, lipectomy, lipodystrophy, ...
# 9                     [echocardiogram, and, doppler]

# %% [markdown]
# **STEP 13 : Remove the stopwords**

# %%
# Importing stop words from NLTK corpus for english language
import nltk
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
stop_words
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
NER_df['NER_token_filtered'] = NER_df['NER_token'].apply(lambda x: [word for word in x if not word in stop_words])

NER_df[['NER_token', 'NER_token_filtered']].head(10)
# Out:
#                                            NER_token  \
# 0  [year, old, white, female, presents, with, com...
# 1      [consult, for, laparoscopic, gastric, bypass]
# 2      [consult, for, laparoscopic, gastric, bypass]
# 3                                    [mode, doppler]
# 4                                   [echocardiogram]
# 5  [morbid, obesity, laparoscopic, antecolic, ant...
# 6  [liposuction, of, the, supraumbilical, abdomen...
# 7                                   [echocardiogram]
# 8  [suction, assisted, lipectomy, lipodystrophy, ...
# 9                     [echocardiogram, and, doppler]
#
#                                   NER_token_filtered
# 0  [year, old, white, female, presents, complaint...
# 1           [consult, laparoscopic, gastric, bypass]
# 2           [consult, laparoscopic, gastric, bypass]
# 3                                    [mode, doppler]
# 4                                   [echocardiogram]
# 5  [morbid, obesity, laparoscopic, antecolic, ant...
# 6  [liposuction, supraumbilical, abdomen, revisio...
# 7                                   [echocardiogram]
# 8  [suction, assisted, lipectomy, lipodystrophy, ...
# 9                          [echocardiogram, doppler]

# %% [markdown]
# **STEP 14: Text Normalization**

# %% [markdown]
# Normalization is helpful in reducing the number of unique tokens present in the text, removing the variations in a text. and also cleaning the text by removing redundant information.
#
# Two popular methods used for normalization are stemming and lemmatization. Let’s discuss them in detail. Nevertheless, for this purpose, I will be creating two columns, one for stemming and another one for lemmatization

# %% [markdown]
# **A. Stemming**

# %%
# Importing library for stemming
from nltk.stem import PorterStemmer
# Initialize the stemming object
stemming = PorterStemmer()

# %%
# Created one more columns tweet_stemmed it shows tweets' stemmed version
NER_df['NER_stemmed'] = NER_df['NER_token_filtered'].apply(lambda x: ' '.join([stemming.stem(i) for i in x]))
NER_df['NER_stemmed'].head(10)
# Out:
# 0       year old white femal present complaint allergi
# 1                    consult laparoscop gastric bypass
# 2                    consult laparoscop gastric bypass
# 3                                         mode doppler
# 4                                       echocardiogram
# 5    morbid obes laparoscop antecol antegastr roux ...
# 6    liposuct supraumbil abdomen revis right breast...
# 7                                       echocardiogram
# 8    suction assist lipectomi lipodystrophi abdomen...
# 9                               echocardiogram doppler
# Name: NER_stemmed, dtype: object

# %% [markdown]
# **B. Lemmatization**

# %%
# Importing library for lemmatizing
import nltk
nltk.download('wordnet')
from nltk.stem.wordnet import WordNetLemmatizer
lemmatizing = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %% [markdown]
# Created one more columns tweet_lemmatized it shows tweets' lemmatized version

# %%
NER_df['NER_lemmatized'] = NER_df['NER_token_filtered'].apply(lambda x: ' '.join([lemmatizing.lemmatize(i) for i in x]))
NER_df['NER_lemmatized'].head(10)
# Out:
# 0      year old white female present complaint allergy
# 1                  consult laparoscopic gastric bypass
# 2                  consult laparoscopic gastric bypass
# 3                                         mode doppler
# 4                                       echocardiogram
# 5    morbid obesity laparoscopic antecolic antegast...
# 6    liposuction supraumbilical abdomen revision ri...
# 7                                       echocardiogram
# 8    suction assisted lipectomy lipodystrophy abdom...
# 9                               echocardiogram doppler
# Name: NER_lemmatized, dtype: object

# %%
NER_df.head(3)
# Out:
#                                          description  \
# 0   A 23-year-old white female presents with comp...
# 1           Consult for laparoscopic gastric bypass.
# 2           Consult for laparoscopic gastric bypass.
#
#                                        transcription  \
# 0  SUBJECTIVE:,  This 23-year-old white female pr...
# 1  PAST MEDICAL HISTORY:, He has difficulty climb...
# 2  HISTORY OF PRESENT ILLNESS: , I have seen ABC ...
#
#                                             keywords  \
# 0  allergy / immunology, allergic rhinitis, aller...
# 1  bariatrics, laparoscopic gastric bypass, weigh...
# 2  bariatrics, laparoscopic gastric bypass, heart...
#
#                                           clean_desc  \
# 0  year old white female presents with complaint ...
# 1            consult for laparoscopic gastric bypass
# 2            consult for laparoscopic gastric bypass
#
#                                            NER_token  \
# 0  [year, old, white, female, presents, with, com...
# 1      [consult, for, laparoscopic, gastric, bypass]
# 2      [consult, for, laparoscopic, gastric, bypass]
#
#                                   NER_token_filtered  \
# 0  [year, old, white, female, presents, complaint...
# 1           [consult, laparoscopic, gastric, bypass]
# 2           [consult, laparoscopic, gastric, bypass]
#
#                                       NER_stemmed  \
# 0  year old white femal present complaint allergi
# 1               consult laparoscop gastric bypass
# 2               consult laparoscop gastric bypass
#
#                                     NER_lemmatized
# 0  year old white female present complaint allergy
# 1              consult laparoscopic gastric bypass
# 2              consult laparoscopic gastric bypass

# %%
# !python -m spacy download en_core_web_sm

# %% [markdown]
# # **STEP 15: Parts-of-speech tagging (POS Tagging)**

# %%
import spacy
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
test_data1= NER_df['clean_desc'].to_string()

# %%
doc = nlp(test_data1)
fmt_str = "{:<8}| {:<6}| {:<8}| {:<8}"
print(fmt_str.format("token","pos", "label","parent"))
for token in doc:
    print(fmt_str.format(token.text, token.pos_, token.ent_type_, token.head.text))
# Out:
# Streaming output truncated to the last 5000 lines.
#
#        | SPACE |         | ...
# 4264    | NUM   | DATE    | consultation
#         | SPACE |         | 4264
# neurologic| ADJ   |         | consultation
# consultation| NOUN  |         | requested
# was     | AUX   |         | requested
# requested| VERB  |         | requested
# to      | ADP   |         | requested
# evalu   | VERB  |         | to
# ...     | PUNCT |         | requested
#
#        | SPACE |         | ...
# 4268    | NUM   | DATE    | 4268
#         | SPACE |         | 4268
# the     | DET   |         | patient
# patient | NOUN  |         | admitted
# is      | AUX   |         | admitted
# admitted| VERB  |         | admitted
# with    | ADP   |         | admitted
# diagnosis| NOUN  |         | with
# of      | ADP   |         | diagnosis
# acut    | NOUN  |         | of
# ...     | PUNCT |         | admitted
#
#        | SPACE |         | ...
# 4269    | NUM   | DATE    | patient
#         | SPACE |         | 4269
# patient | ADJ   |         | secondary
# with    | ADP   |         | patient
# end     | NOUN  |         | disease
# stage   | NOUN  |         | disease
# renal   | ADJ   |         | disease
# disease | NOUN  |         | with
# secondary| ADJ   |         | secondary
# ...     | PUNCT |         | secondary
#
#        | SPACE |         | ...
# 4270    | NUM   | CARDINAL| patient
#         | SPACE |         | 4270
# patient | ADJ   |         | develop
# with    | ADP   |         | patient
# diagnosis| NOUN  |         | with
# of      | ADP   |         | diagnosis
# pancreatitis| NOUN  |         | of
# develop | VERB  |         | develop
# ...     | PUNCT |         | develop
#
#        | SPACE |         | ...
# 4274    | NUM   | DATE    | 4274
#         | SPACE |         | 4274
# mm      | PROPN | PERSON  | left
# left    | VERB  |         | left
# intrarenal| ADJ   |         | stone
# stone   | NOUN  |         | left
# nonobstructing| VERB  |         | left
# by      | ADP   |         | nonobstructing
# ult     | NOUN  |         | by
# ...     | PUNCT |         | left
#
#        | SPACE |         | ...
# 4275    | NUM   | CARDINAL| patient
#         | SPACE |         | 4275
# patient | ADJ   |         | patient
# with    | ADP   |         | patient
# stable  | ADJ   |         | aphasia
# expressive| NOUN  |         | aphasia
# aphasia | PROPN | GPE     | with
# and     | CCONJ |         | aphasia
# dec     | PROPN |         | ...
# ...     | PUNCT |         | patient
#
#        | SPACE |         | ...
# 4277    | NUM   | DATE    | loculated
#         | SPACE |         | 4277
# loculated| VERB  |         | loculated
# left    | ADJ   |         | p
# effusion| NOUN  |         | p
# multilobar| NOUN  |         | p
# pneumonia| NOUN  |         | p
# p       | NOUN  |         | loculated
# ...     | PUNCT |         | p
#
#        | SPACE |         | ...
# 4281    | NUM   | CARDINAL| loss
#                  | SPACE |         | 4281
# progressive| ADJ   |         | loss
# loss    | NOUN  |         | loss
# of      | ADP   |         | loss
# color   | NOUN  |         | vision
# vision  | NOUN  |         | of
# od      | PROPN |         | loss
#
#        | SPACE |         | od
# 4282    | NUM   | CARDINAL| changes
#         | SPACE |         | 4282
# mental  | ADJ   |         | changes
# status  | NOUN  |         | changes
# changes | NOUN  |         | changes
# after   | ADP   |         | changes
# fall    | NOUN  |         | after
# she     | PRON  |         | sustained
# sustained| VERB  |         | sustained
# ...     | PUNCT |         | sustained
#
#        | SPACE |         | ...
# 4285    | NUM   | CARDINAL| patient
#         | SPACE |         | 4285
# patient | NOUN  |         | presented
# presented| VERB  |         | presented
# with    | ADP   |         | presented
# significant| ADJ   |         | trem
# muscle  | NOUN  |         | trem
# trem    | NOUN  |         | with
# ...     | PUNCT |         | presented
#
#        | SPACE |         | ...
# 4286    | NUM   | CARDINAL| patient
#         | SPACE |         | 4286
# patient | ADJ   |         | patient
# with    | ADP   |         | patient
# sudden  | ADJ   |         | dizziness
# onset   | NOUN  |         | dizziness
# dizziness| NOUN  |         | with
# and     | CCONJ |         | dizziness
# rue     | X     | GPE     | cl
# cl      | PROPN | GPE     | dizziness
# ...     | PUNCT |         | patient
#
#        | SPACE |         | ...
# 4287    | NUM   | DATE    | problems
#         | SPACE |         | 4287
# problems| NOUN  |         | been
# with    | ADP   |         | problems
# seizures| NOUN  |         | hemiparesis
# hemiparesis| NOUN  |         | with
# has     | AUX   |         | been
# been    | AUX   |         | been
# to      | ADP   |         | been
# ...     | PUNCT |         | been
#
#        | SPACE |         | ...
# 4289    | NUM   | DATE    | pain
#         | SPACE |         | 4289
# low     | ADJ   |         | back
# back    | ADJ   |         | 4289
# pain    | NOUN  |         | pain
# lumbar  | PROPN |         | radiculopathy
# radiculopathy| ADJ   |         | degenerativ
# degenerativ| PROPN |         | degenerativ
# ...     | PUNCT |         | degenerativ
#
#        | SPACE |         | ...
# 4294    | NUM   | DATE    | strain
#         | SPACE |         | 4294
# lumbar  | PROPN |         | muscle
# muscle  | NOUN  |         | strain
# strain  | NOUN  |         | strain
# and     | CCONJ |         | strain
# chronic | VERB  |         | strain
# back    | ADP   |         | pain
# pain    | NOUN  |         | pat
# pat     | NOUN  |         | chronic
# ...     | PUNCT |         | strain
#
#        | SPACE |         | ...
# 4296    | NUM   | DATE    | consultation
#         | SPACE |         | 4296
# new     | ADJ   |         | consultation
# patient | NOUN  |         | consultation
# consultation| NOUN  |         | consultation
# low     | ADJ   |         | back
# back    | ADJ   |         | degener
# pain    | NOUN  |         | degener
# degener | NOUN  |         | consultation
# ...     | PUNCT |         | consultation
#
#        | SPACE |         | ...
# 4297    | NUM   | CARDINAL| month
#         | SPACE |         | 4297
# month   | NOUN  |         | old
# old     | ADJ   |         | male
# male    | NOUN  |         | presented
# presented| VERB  |         | presented
# for     | ADP   |         | presented
# delayed | ADJ   |         | dev
# motor   | NOUN  |         | dev
# dev     | PROPN |         | for
# ...     | PUNCT |         | presented
#
#        | SPACE |         | ...
# 4298    | NUM   | CARDINAL| patient
#         | SPACE |         | 4298
# patient | ADJ   |         | patient
# with    | ADP   |         | patient
# year    | NOUN  |         | history
# history | NOUN  |         | with
# of      | ADP   |         | history
# progressive| ADJ   |         | anter
# anter   | NOUN  |         | of
# ...     | PUNCT |         | patient
#
#        | SPACE |         | ...
# 4300    | NUM   | CARDINAL| 4300
#         | SPACE |         | 4300
# the     | DET   |         | patient
# patient | NOUN  |         | comes
# comes   | VERB  |         | comes
# in      | ADP   |         | comes
# today   | NOUN  | DATE    | comes
# because | SCONJ |         | comes
# of      | ADP   |         | because
# feeling | NOUN  |         | because
# ...     | PUNCT |         | comes
#
#        | SPACE |         | ...
# 4301    | NUM   | DATE    | urine
#         | SPACE |         | 4301
# urine   | NOUN  |         | leaked
# leaked  | VERB  |         | leaked
# around  | ADP   |         | leaked
# the     | DET   |         | site
# ostomy  | NOUN  |         | site
# site    | NOUN  |         | around
# for     | ADP   |         | leaked
# his     | DET   |         | ri
# ri      | NOUN  |         | for
# ...     | PUNCT |         | leaked
#
#        | SPACE |         | ...
# 4305    | NUM   | DATE    | 4305
#              | SPACE |         | 4305
# consult | PROPN |         | consult
# for     | ADP   |         | consult
# laparoscopic| PROPN |         | bypass
# gastric | PROPN |         | bypass
# bypass  | PROPN |         | for
#
#        | SPACE |         | bypass
# 4306    | NUM   |         | 4306
#              | SPACE |         | 4306
# consult | PROPN |         | consult
# for     | ADP   |         | consult
# laparoscopic| PROPN |         | bypass
# gastric | PROPN |         | bypass
# bypass  | PROPN |         | for
#
#        | SPACE |         | bypass
# 4307    | NUM   | PRODUCT | 4307
#         | SPACE |         | 4307
# the     | DET   |         | patient
# patient | NOUN  |         | is
# with    | ADP   |         | patient
# an      | DET   |         | fracture
# compression| NOUN  |         | fracture
# fracture| NOUN  |         | with
# is      | AUX   |         | is
# to      | PART  |         | is
# ...     | PUNCT |         | is
#
#        | SPACE |         | ...
# 4308    | NUM   | CARDINAL| evaluation
#         | SPACE |         | 4308
# year    | NOUN  |         | old
# old     | ADJ   |         | evaluation
# new     | ADJ   |         | evaluation
# patientfor| NOUN  |         | evaluation
# evaluation| NOUN  |         | evaluation
# of      | ADP   |         | evaluation
# thoracic| PROPN | GPE     | of
# ...     | PUNCT |         | evaluation
#
#        | SPACE |         | ...
# 4309    | NUM   | DATE    | 4309
#         | SPACE |         | 4309
# this    | DET   |         | year
# year    | NOUN  | DATE    | awoke
# old     | ADJ   |         | gentleman
# gentleman| PROPN |         | awoke
# awoke   | VERB  |         | awoke
# this    | DET   | TIME    | morning
# morning | NOUN  | TIME    | awoke
# not     | PART  |         | awoke
# ...     | PUNCT |         | awoke
#
#        | SPACE |         | ...
# 4310    | NUM   | DATE    | 4310
#         | SPACE |         | 4310
# right   | INTJ  |         | suggestive
# knee    | NOUN  |         | suggestive
# injury  | NOUN  |         | suggestive
# suggestive| NOUN  |         | suggestive
# of      | ADP   |         | suggestive
# recurrent| ADJ   |         | ante
# ante    | NOUN  |         | of
# ...     | PUNCT |         | suggestive
#
#        | SPACE |         | ...
# 4311    | NUM   | DATE    | patient
#         | SPACE |         | 4311
# patient | NOUN  |         | started
# started | VERB  |         | started
# out     | ADP   |         | started
# having  | VERB  |         | started
# toothache| PROPN |         | having
# now     | ADV   |         | radia
# radia   | PROPN |         | having
# ...     | PUNCT |         | started
#
#        | SPACE |         | ...
# 4312    | NUM   | DATE    | pneumatosis
#         | SPACE |         | 4312
# pneumatosis| NOUN  |         | coli
# coli    | NOUN  |         | coli
# in      | ADP   |         | coli
# the     | DET   |         | cecum
# cecum   | ADJ   |         | in
# possible| ADJ   |         | cecum
# ischemi | NOUN  |         | ischemi
# ...     | PUNCT |         | ischemi
#
#        | SPACE |         | ...
# 4313    | NUM   | DATE    | epilepsy
#              | SPACE |         | 4313
# intractable| ADJ   |         | epilepsy
# epilepsy| NOUN  |         | epilepsy
# here    | ADV   |         | epilepsy
# for     | ADP   |         | epilepsy
# video   | NOUN  |         | eeg
# eeg     | PROPN |         | for
#
#        | SPACE |         | eeg
# 4314    | NUM   | CARDINAL| anemia
#         | SPACE |         | 4314
# iron    | NOUN  |         | deficiency
# deficiency| NOUN  |         | anemia
# anemia  | NOUN  |         | underwent
# she     | PRON  |         | underwent
# underwent| VERB  |         | underwent
# bone    | NOUN  |         | marr
# marr    | PROPN |         | underwent
# ...     | PUNCT |         | underwent
#
#        | SPACE |         | ...
# 4315    | NUM   | CARDINAL| hematoma
#         | SPACE |         | 4315
# right   | ADV   |         | hematoma
# iliopsoas| PROPN |         | hematoma
# hematoma| VERB  |         | hematoma
# with    | ADP   |         | hematoma
# associated| PROPN |         | femor
# femor   | PROPN |         | with
# ...     | PUNCT |         | hematoma
#
#        | SPACE |         | ...
# 4317    | NUM   | DATE    | supr
#         | SPACE |         | 4317
# right   | ADJ   |         | shoulder
# shoulder| PROPN |         | syndrome
# impingement| PROPN |         | syndrome
# syndrome| PROPN |         | supr
# right   | PROPN |         | supr
# supr    | PROPN |         | supr
# ...     | PUNCT |         | supr
#
#        | SPACE |         | ...
# 4318    | NUM   | CARDINAL| complaint
#         | SPACE |         | 4318
# chief   | ADJ   |         | complaint
# complaint| NOUN  |         | diagn
# of      | ADP   |         | complaint
# chest   | NOUN  |         | pain
# pain    | NOUN  |         | of
# previously| ADV   |         | diagn
# diagn   | VERB  |         | diagn
# ...     | PUNCT |         | diagn
#
#        | SPACE |         | ...
# 4320    | NUM   | CARDINAL| coron
#         | SPACE |         | 4320
# nonischemic| PROPN |         | coron
# cardiomyopathy| PROPN |         | coron
# branch  | NOUN  |         | vessel
# vessel  | NOUN  |         | coron
# coron   | PROPN |         | coron
# ...     | PUNCT |         | coron
#
#        | SPACE |         | ...
# 4321    | NUM   | DATE    | reaction
#         | SPACE |         | 4321
# local   | ADJ   |         | reaction
# reaction| NOUN  |         | reaction
# secondary| ADJ   |         | reaction
# to      | PART  |         | insect
# insect  | VERB  |         | reaction
# sting   | VERB  |         | insect
# patie   | NOUN  |         | sting
# ...     | PUNCT |         | reaction
#
#        | SPACE |         | ...
# 4326    | NUM   | DATE    | 4326
#         | SPACE |         | 4326
# likely  | ADJ   |         | molluscum
# molluscum| NOUN  |         | molluscum
# contagiosum| NOUN  |         | molluscum
# genital | PROPN |         | warts
# warts   | PROPN |         | warts
# cau     | PROPN |         | cau
# ...     | PUNCT |         | cau
#
#        | SPACE |         | ...
# 4327    | NUM   | DATE    | woman
#         | SPACE |         | 4327
# an      | DET   |         | year
# year    | NOUN  | DATE    | old
# old     | ADJ   |         | woman
# woman   | NOUN  |         | woman
# with    | ADP   |         | woman
# history | NOUN  |         | with
# of      | ADP   |         | history
# hypertension| NOUN  |         | of
# ...     | PUNCT |         | woman
#
#        | SPACE |         | ...
# 4329    | NUM   | CARDINAL| patient
#         | SPACE |         | 4329
# patient | NOUN  |         | comes
# comes   | VERB  |         | comes
# in      | ADV   |         | comes
# for     | ADP   |         | comes
# initial | ADJ   |         | evaluation
# evaluation| NOUN  |         | for
# of      | ADP   |         | evaluation
# hyp     | PROPN |         | of
# ...     | PUNCT |         | comes
#
#        | SPACE |         | ...
# 4332    | NUM   | DATE    | left
#         | SPACE |         | 4332
# left    | VERB  |         | left
# hip     | NOUN  |         | fracture
# fracture| VERB  |         | left
# the     | DET   |         | patient
# patient | NOUN  |         | is
# is      | AUX   |         | is
# year    | NOUN  | DATE    | old
# old     | ADJ   |         | fema
# fema    | PROPN |         | is
# ...     | PUNCT |         | is
#
#        | SPACE |         | ...
# 4336    | NUM   | DATE    | closed
#         | SPACE |         | 4336
# closed  | ADJ   |         | closed
# head    | NOUN  |         | injury
# injury  | NOUN  |         | closed
# with    | ADP   |         | closed
# evidence| NOUN  |         | with
# of      | ADP   |         | evidence
# axonal  | ADJ   |         | inj
# inj     | NOUN  |         | of
# ...     | PUNCT |         | closed
#
#        | SPACE |         | ...
# 4337    | NUM   | CARDINAL| 4337
#         | SPACE |         | 4337
# patient | NOUN  |         | presents
# presents| NOUN  |         | presents
# with    | ADP   |         | presents
# gross   | ADJ   |         | hematuria
# hematuria| NOUN  |         | with
# that    | DET   |         | sta
# sta     | PROPN |         | presents
# ...     | PUNCT |         | presents
#
#        | SPACE |         | ...
# 4339    | NUM   | CARDINAL| visit
#         | SPACE |         | 4339
# new     | ADJ   |         | visit
# patient | ADJ   |         | visit
# visit   | NOUN  |         | punched
# for     | ADP   |         | visit
# right   | ADJ   |         | pain
# hand    | NOUN  |         | pain
# pain    | NOUN  |         | for
# punched | VERB  |         | punched
# ...     | PUNCT |         | punched
#
#        | SPACE |         | ...
# 4350    | NUM   | CARDINAL| glioma
#                   | SPACE |         | 4350
# headache| PROPN |         | frontal
# right   | PROPN |         | frontal
# frontal | PROPN |         | glioma
# lobe    | PROPN |         | glioma
# glioma  | PROPN |         | glioma
#
#        | SPACE |         | glioma
# 4357    | NUM   | DATE    | glioma
#         | SPACE |         | 4357
# comprehensive| ADJ   |         | evaluation
# evaluation| NOUN  |         | diabetes
# diabetes| VERB  |         | diabetes
# hypertension| NOUN  |         | diabetes
# ...     | PUNCT |         | diabetes
#
#        | SPACE |         | ...
# 4358    | NUM   | DATE    | consultation
#         | SPACE |         | 4358
# gi      | PROPN |         | consultation
# consultation| NOUN  |         | consultation
# due     | ADP   |         | consultation
# to      | ADP   |         | due
# rectal  | ADJ   |         | positiv
# bleeding| NOUN  |         | positiv
# positiv | NOUN  |         | due
# ...     | PUNCT |         | consultation
#
#        | SPACE |         | ...
# 4362    | NUM   | DATE    | evaluation
#         | SPACE |         | 4362
# comprehensive| ADJ   |         | evaluation
# evaluation| NOUN  |         | generalized
# generalized| VERB  |         | generalized
# anxiety | NOUN  |         | a
# a       | NOUN  |         | generalized
# ...     | PUNCT |         | a
#
#        | SPACE |         | ...
# 4363    | NUM   | DATE    | patient
#         | SPACE |         | 4363
# patient | ADJ   |         | patient
# with    | ADP   |         | patient
# swelling| NOUN  |         | with
# of      | ADP   |         | swelling
# lips    | NOUN  |         | of
# and     | CCONJ |         | lips
# dysphagia| PROPN |         | an
# an      | DET   |         | an
# ...     | PUNCT |         | an
#
#        | SPACE |         | ...
# 4370    | NUM   | CARDINAL| pain
#         | SPACE |         | 4370
# anxiety | PROPN |         | alcohol
# alcohol | NOUN  |         | pain
# abuse   | NOUN  |         | pain
# and     | CCONJ |         | abuse
# chest   | NOUN  |         | abuse
# pain    | NOUN  |         | pain
# this    | DET   |         | is
# is      | AUX   |         | is
# y       | NOUN  |         | is
# ...     | PUNCT |         | is
#
#        | SPACE |         | ...
# 4371    | NUM   | CARDINAL| 4371
#         | SPACE |         | 4371
# the     | DET   |         | patient
# patient | NOUN  |         | had
# had     | AUX   |         | had
# temperature| NOUN  |         | had
# of      | ADP   |         | temperature
# degrees | NOUN  |         | of
# it      | PRON  |         | has
# has     | AUX   |         | degrees
# ...     | PUNCT |         | had
#
#        | SPACE |         | ...
# 4373    | NUM   | DATE    | female
#         | SPACE | DATE    | 4373
# year    | NOUN  | DATE    | female
# old     | ADJ   | DATE    | female
# female  | NOUN  |         | female
# with    | ADP   |         | female
# past    | ADJ   |         | history
# history | NOUN  |         | with
# of      | ADP   |         | history
# type    | NOUN  |         | d
# ii      | NOUN  |         | d
# d       | NOUN  |         | of
# ...     | PUNCT |         | female
#
#        | SPACE |         | ...
# 4376    | NUM   | CARDINAL| 4376
#         | SPACE |         | 4376
# backache| PROPN |         | stomachache
# stomachache| PROPN |         | 4376
# and     | CCONJ |         | stomachache
# dysuria | PROPN |         | stomachache
# for     | ADP   |         | stomachache
# the     | DET   |         | last
# last    | ADJ   |         | for
# ...     | PUNCT |         | 4376
#
#        | SPACE |         | ...
# 4390    | NUM   | DATE    | man
#             | SPACE | DATE    | 4390
# year    | NOUN  | DATE    | old
# old     | ADJ   | DATE    | man
# young   | ADJ   |         | man
# man     | NOUN  |         | man
# with    | ADP   |         | man
# sinus   | NOUN  |         | congestion
# congestion| NOUN  |         | with
#
#        | SPACE |         | congestion
# 4392    | NUM   | CARDINAL| patient
#         | SPACE |         | 4392
# patient | NOUN  |         | patient
# in      | ADP   |         | patient
# with    | ADP   |         | in
# mom     | NOUN  |         | with
# for     | ADP   |         | patient
# possible| ADJ   |         | infection
# ear     | NOUN  |         | infection
# infection| NOUN  |         | for
#
#        | SPACE |         | infection
# 4393    | NUM   | CARDINAL| 4393
#         | SPACE |         | 4393
# the     | DET   |         | patient
# patient | NOUN  |         | patient
# brought | VERB  |         | patient
# in      | ADP   |         | brought
# by      | ADP   |         | brought
# ems     | PROPN | ORG     | by
# with    | ADP   |         | ems
# complaint| NOUN  |         | o
# o       | NOUN  |         | with
# ...     | PUNCT |         | patient
#
#        | SPACE |         | ...
# 4395    | NUM   | PRODUCT | 4395
#                   | SPACE |         | 4395
# nausea  | NOUN  |         | diarrhea
# vomiting| NOUN  |         | diarrhea
# diarrhea| NOUN  |         | 4395
# and     | CCONJ |         | diarrhea
# fever   | NOUN  |         | diarrhea
#
#        | SPACE |         | fever
# 4396    | NUM   | DATE    | girl
#         | SPACE |         | 4396
# year    | NOUN  | DATE    | old
# old     | ADJ   | DATE    | girl
# little  | ADJ   |         | girl
# girl    | NOUN  |         | girl
# with    | ADP   |         | girl
# stuffiness| ADJ   |         | congestio
# congestio| NOUN  |         | with
# ...     | PUNCT |         | girl
#
#        | SPACE |         | ...
# 4397    | NUM   | DATE    | history
#         | SPACE |         | 4397
# year    | NOUN  |         | history
# old     | ADJ   |         | history
# female  | ADJ   |         | history
# history | NOUN  |         | history
# of      | ADP   |         | history
# congestion| NOUN  |         | of
# possibly| ADV   |         | history
# ...     | PUNCT |         | history
#
#        | SPACE |         | ...
# 4398    | NUM   | DATE    | patient
#         | SPACE |         | 4398
# patient | ADJ   |         | patient
# with    | ADP   |         | patient
# intermittent| ADJ   |         | episodes
# episodes| NOUN  |         | with
# of      | ADP   |         | episodes
# severe  | ADJ   |         | n
# n       | PROPN |         | ...
# ...     | PUNCT |         | patient
#
#        | SPACE |         | ...
# 4401    | NUM   | DATE    | male
#         | SPACE |         | 4401
# year    | NOUN  | DATE    | male
# old     | ADJ   |         | male
# male    | NOUN  |         | male
# who     | PRON  |         | comes
# comes   | VERB  |         | male
# in      | ADP   |         | comes
# with    | ADP   |         | comes
# cough   | NOUN  |         | with
# and     | CCONJ |         | cough
# cong    | PROPN |         | cough
# ...     | PUNCT |         | male
#
#        | SPACE |         | ...
# 4402    | NUM   | DATE    | 4402
#         | SPACE |         | 4402
# an      | DET   |         | month
# month   | NOUN  | DATE    | old
# old     | ADJ   |         | male
# white   | ADJ   |         | male
# male    | NOUN  |         | male
# here    | ADV   |         | male
# with    | ADP   |         | male
# his     | DET   |         | mother
# mother  | NOUN  |         | with
# f       | PROPN |         | mother
# ...     | PUNCT |         | male
#
#        | SPACE |         | ...
# 4403    | NUM   | DATE    | 4403
#         | SPACE |         | 4403
# year    | NOUN  |         | female
# old     | ADJ   |         | female
# female  | NOUN  |         | female
# who     | PRON  |         | comes
# comes   | VERB  |         | female
# in      | ADP   |         | comes
# for     | ADP   |         | comes
# just    | ADV   |         | rechecki
# rechecki| PROPN |         | for
# ...     | PUNCT |         | female
#
#        | SPACE |         | ...
# 4404    | NUM   | DATE    | loss
#         | SPACE |         | 4404
# short   | ADJ   |         | term
# term    | NOUN  |         | loss
# memory  | NOUN  |         | loss
# loss    | NOUN  |         | situational
# probable| ADJ   |         | situational
# situational| ADJ   |         | an
# an      | DET   |         | an
# ...     | PUNCT |         | an
#
#        | SPACE |         | ...
# 4405    | NUM   | CARDINAL| complaint
#             | SPACE |         | 4405
# complaint| NOUN  |         | complaint
# of      | ADP   |         | complaint
# mood    | NOUN  |         | swings
# swings  | NOUN  |         | of
# and     | CCONJ |         | complaint
# tearfulness| NOUN  |         | complaint
#
#        | SPACE |         | tearfulness
# 4412    | NUM   | CARDINAL| return
#               | SPACE |         | 4412
# return  | NOUN  |         | return
# to      | ADP   |         | work
# work    | NOUN  |         | return
# fit     | NOUN  |         | work
# for     | ADP   |         | fit
# duty    | NOUN  |         | evaluation
# evaluation| NOUN  |         | for
#
#        | SPACE |         | evaluation
# 4413    | NUM   | CARDINAL| patient
#         | SPACE |         | 4413
# patient | NOUN  |         | presented
# presented| VERB  |         | presented
# to      | ADP   |         | presented
# the     | DET   |         | ser
# bariatric| ADJ   |         | ser
# surgery | NOUN  |         | ser
# ser     | NOUN  |         | to
# ...     | PUNCT |         | presented
#
#        | SPACE |         | ...
# 4414    | NUM   | CARDINAL| patient
#         | SPACE |         | 4414
# patient | NOUN  |         | patient
# scheduled| VERB  |         | patient
# for     | ADP   |         | scheduled
# laparoscopic| PROPN |         | bypass
# gastric | PROPN |         | bypass
# bypass  | PROPN |         | for
#
#        | SPACE |         | bypass
# 4415    | NUM   | CARDINAL| history
#         | SPACE |         | 4415
# pediatric| ADJ   |         | gastroenterology
# gastroenterology| NOUN  |         | history
# history | NOUN  |         | bypass
# of      | ADP   |         | history
# gagging | VERB  |         | of
#
#        | SPACE |         | gagging
# 4416    | NUM   | DATE    | body
#         | SPACE |         | 4416
# foreign | ADJ   |         | body
# body    | NOUN  |         | gagging
# of      | ADP   |         | body
# the     | DET   |         | wood
# left    | ADJ   |         | wood
# fifth   | ADJ   | ORDINAL | wood
# fingernail| NOUN  |         | wood
# wood    | NOUN  |         | of
# ...     | PUNCT |         | patient
#
#        | SPACE |         | ...
# 4417    | NUM   | CARDINAL| gentleman
#         | SPACE |         | 4417
# gentleman| PROPN |         | gentleman
# with    | ADP   |         | gentleman
# long    | ADJ   |         | obesity
# standing| PROPN |         | obesity
# morbid  | NOUN  |         | obesity
# obesity | NOUN  |         | with
# re      | NOUN  |         | ...
# ...     | PUNCT |         | gentleman
#
#        | SPACE |         | ...
# 4418    | NUM   | DATE    | abscess
#         | SPACE |         | 4418
# abscess | NOUN  |         | abscess
# of      | ADP   |         | abscess
# the     | DET   |         | etiology
# left    | ADJ   |         | foot
# foot    | NOUN  |         | etiology
# etiology| NOUN  |         | of
# unclear | ADJ   |         | abscess
# at      | ADP   |         | abscess
# t       | NOUN  |         | at
# ...     | PUNCT |         | abscess
#
#        | SPACE |         | ...
# 4420    | NUM   | CARDINAL| consultation
#                      | SPACE |         | 4420
# consultation| NOUN  |         | consultation
# for     | ADP   |         | consultation
# left    | ADJ   |         | pain
# foot    | NOUN  |         | pain
# pain    | NOUN  |         | for
#
#        | SPACE |         | pain
# 4422    | NUM   | CARDINAL| body
#         | SPACE |         | 4422
# questionable| ADJ   |         | body
# foreign | ADJ   |         | body
# body    | NOUN  |         | right
# right   | ADJ   |         | belly
# nose    | NOUN  |         | belly
# belly   | NOUN  |         | belly
# and     | CCONJ |         | and
# ...     | PUNCT |         | and
#
#        | SPACE |         | ...
# 4423    | NUM   | CARDINAL| left
#                       | SPACE |         | 4423
# left    | VERB  |         | left
# flank   | PROPN |         | pain
# pain    | NOUN  |         | stone
# ureteral| PROPN |         | stone
# stone   | PROPN |         | left
#
#        | SPACE |         | stone
# 4429    | NUM   | CARDINAL| left
#                | SPACE |         | 4429
# left    | VERB  |         | left
# flank   | NOUN  |         | pain
# pain    | NOUN  |         | left
# and     | CCONJ |         | pain
# unable  | ADJ   |         | pain
# to      | PART  |         | urinate
# urinate | VERB  |         | unable
#
#        | SPACE |         | urinate
# 4430    | NUM   | CARDINAL| 4430
#         | SPACE |         | 4430
# this    | DET   |         | year
# year    | NOUN  | DATE    | has
# old     | ADJ   |         | female
# white   | ADJ   |         | female
# female  | NOUN  |         | has
# has     | AUX   |         | has
# essential| ADJ   |         | tremo
# tremo   | NOUN  |         | has
# ...     | PUNCT |         | has
#
#        | SPACE |         | ...
# 4431    | NUM   | DATE    | fall
#         | SPACE |         | 4431
# fall    | VERB  |         | fall
# with    | ADP   |         | fall
# questionable| ADJ   |         | loss
# associated| VERB  |         | loss
# loss    | NOUN  |         | with
# of      | ADP   |         | loss
# cons    | NOUN  |         | of
# ...     | PUNCT |         | fall
#
#        | SPACE |         | ...
# 4432    | NUM   | DATE    | loss
#                           | SPACE |         | 4432
# fall    | VERB  |         | loss
# loss    | NOUN  |         | loss
# of      | ADP   |         | loss
# consciousness| NOUN  |         | of
#
#        | SPACE |         | consciousness
# 4438    | NUM   | CARDINAL| chronic
#         | SPACE |         | 4438
# chronic | ADJ   |         | chronic
# eustachian| ADJ   |         | tube
# tube    | NOUN  |         | dysfunction
# dysfunction| NOUN  |         | chronic
# chronic | NOUN  |         | chronic
# ot      | PROPN |         | chronic
# ...     | PUNCT |         | chronic
#
#        | SPACE |         | ...
# 4440    | NUM   | CARDINAL| left
#         | SPACE |         | 4440
# left    | VERB  |         | left
# elbow   | ADJ   |         | pain
# pain    | NOUN  |         | fracture
# fracture| NOUN  |         | left
# of      | ADP   |         | fracture
# the     | DET   |         | spiral
# humerus | NOUN  |         | spiral
# spiral  | NOUN  |         | of
# ...     | PUNCT |         | left
#
#        | SPACE |         | ...
# 4443    | NUM   | CARDINAL| patient
#         | SPACE |         | 4443
# patient | NOUN  |         | went
# went    | VERB  |         | went
# out     | ADP   |         | went
# partying| VERB  |         | went
# last    | ADJ   | TIME    | night
# night   | NOUN  | TIME    | partying
# and     | CCONJ |         | partying
# drank   | VERB  |         | partying
# ...     | PUNCT |         | went
#
#        | SPACE |         | ...
# 4446    | NUM   | DATE    | patient
#         | SPACE |         | 4446
# patient | ADJ   |         | patient
# with    | ADP   |         | patient
# episode | NOUN  |         | with
# of      | ADP   |         | episode
# lightheadedness| NOUN  |         | of
# and     | CCONJ |         | lightheadedness
# su      | PROPN |         | su
# ...     | PUNCT |         | su
#
#        | SPACE |         | ...
# 4447    | NUM   | DATE    | 4447
#         | SPACE |         | 4447
# right   | ADV   |         | ear
# ear     | NOUN  |         | pain
# pain    | NOUN  |         | pain
# with    | ADP   |         | pain
# drainage| NOUN  |         | media
# otitis  | NOUN  |         | media
# media   | NOUN  |         | with
# and     | CCONJ |         | pain
# ...     | PUNCT |         | ...
#
#        | SPACE |         | ...
# 4449    | NUM   | DATE    | 4449
#         | SPACE |         | 4449
# year    | NOUN  |         | old
# old     | ADJ   |         | old
# with    | ADP   |         | old
# discoid | ADJ   | ORG     | lupus
# lupus   | PROPN |         | with
# on      | ADP   |         | old
# the     | DET   |         | wit
# control | NOUN  |         | wit
# wit     | NOUN  |         | on
# ...     | PUNCT |         | old
#
#        | SPACE |         | ...
# 4453    | NUM   | DATE    | consultation
#         | SPACE |         | 4453
# dietary | ADJ   |         | consultation
# consultation| NOUN  |         | consultation
# for     | ADP   |         | consultation
# weight  | NOUN  |         | reduction
# reduction| NOUN  |         | seco
# seco    | NOUN  |         | for
# ...     | PUNCT |         | consultation
#
#        | SPACE |         | ...
# 4454    | NUM   | DATE    | disseminated
#         | SPACE |         | 4454
# disseminated| VERB  |         | disseminated
# intravascular| ADJ   | ORG     | coagulation
# coagulation| NOUN  | ORG     | disseminated
# and     | CCONJ |         | coagulation
# str     | PROPN |         | coagulation
# ...     | PUNCT |         | disseminated
#
#        | SPACE |         | ...
# 4455    | NUM   | DATE    | consultation
#         | SPACE |         | 4455
# dietary | ADJ   |         | consultation
# consultation| NOUN  |         | consultation
# for     | ADP   |         | consultation
# hyperlipidemia| PROPN |         | hypert
# hypert  | PROPN |         | for
# ...     | PUNCT |         | consultation
#
#        | SPACE |         | ...
# 4456    | NUM   | DATE    | consultation
#         | SPACE |         | 4456
# dietary | ADJ   |         | consultation
# consultation| NOUN  |         | consultation
# for     | ADP   |         | consultation
# gestational| ADJ   |         | diabetes
# diabetes| NOUN  |         | for
#
#        | SPACE |         | diabetes
# 4457    | NUM   | CARDINAL| consultation
#         | SPACE |         | 4457
# dietary | ADJ   |         | consultation
# consultation| NOUN  |         | consultation
# for     | ADP   |         | consultation
# woman   | NOUN  |         | for
# with    | ADP   |         | woman
# polycystic| NOUN  |         | with
# ...     | PUNCT |         | consultation
#
#        | SPACE |         | ...
# 4458    | NUM   | CARDINAL| consultation
#         | SPACE |         | 4458
# followup| VERB  |         | consultation
# dietary | ADJ   |         | consultation
# consultation| NOUN  |         | consultation
# for     | ADP   |         | consultation
# hyperlipidem| NOUN  |         | for
# ...     | PUNCT |         | consultation
#
#        | SPACE |         | ...
# 4459    | NUM   | DATE    | consult
#         | SPACE |         | 4459
# dietary | PROPN |         | consult
# consult | NOUN  |         | consult
# for     | ADP   |         | consult
# year    | NOUN  | DATE    | american
# old     | ADJ   |         | american
# african | ADJ   | NORP    | american
# american| PROPN | NORP    | for
# ...     | PUNCT |         | consult
#
#        | SPACE |         | ...
# 4460    | NUM   | DATE    | 4460
#         | SPACE |         | 4460
# the     | DET   |         | patient
# patient | NOUN  |         | brought
# is      | AUX   |         | brought
# brought | VERB  |         | brought
# in      | ADP   |         | brought
# by      | ADP   |         | brought
# an      | DET   |         | assistant
# assistant| NOUN  |         | by
# with    | ADP   |         | assistant
# ...     | PUNCT |         | with
#
#        | SPACE |         | ...
# 4461    | NUM   | CARDINAL| 4461
#         | SPACE |         | 4461
# the     | DET   |         | patient
# patient | NOUN  |         | been
# has     | AUX   |         | been
# been    | AUX   |         | been
# successful| ADJ   |         | been
# with    | ADP   |         | successful
# weight  | NOUN  |         | lo
# lo      | PROPN | PERSON  | with
# ...     | PUNCT |         | been
#
#        | SPACE |         | ...
# 4462    | NUM   | DATE    | consultation
#         | SPACE |         | 4462
# dietary | ADJ   |         | consultation
# consultation| NOUN  |         | consultation
# for     | ADP   |         | consultation
# diabetes| NOUN  |         | for
# during  | ADP   |         | consultation
# pregn   | NOUN  | GPE     | during
# ...     | PUNCT |         | consultation
#
#        | SPACE |         | ...
# 4463    | NUM   | CARDINAL| 4463
#         | SPACE |         | 4463
# one     | NUM   | DATE    | week
# week    | NOUN  | DATE    | history
# history | NOUN  |         | history
# of      | ADP   |         | history
# decreased| VERB  |         | vision
# vision  | NOUN  |         | of
# in      | ADP   |         | vision
# the     | DET   |         | le
# le      | NOUN  | GPE     | in
# ...     | PUNCT |         | history
#
#        | SPACE |         | ...
# 4464    | NUM   | DATE    | 4464
#         | SPACE |         | 4464
# counting| VERB  |         | counting
# calorie | NOUN  |         | points
# points  | NOUN  |         | counting
# exercising| VERB  |         | counting
# pretty  | ADJ   |         | regu
# regu    | NOUN  |         | exercising
# ...     | PUNCT |         | counting
#
#        | SPACE |         | ...
# 4465    | NUM   | DATE    | 4465
#         | SPACE |         | 4465
# this    | DET   | DATE    | is
# is      | AUX   | DATE    | is
# year    | NOUN  | DATE    | female
# old     | ADJ   | DATE    | female
# female  | NOUN  |         | is
# who     | PRON  |         | presents
# presents| VERB  |         | female
# with    | ADP   |         | presents
# coup    | NOUN  |         | with
# ...     | PUNCT |         | is
#
#        | SPACE |         | ...
# 4470    | NUM   | DATE    | 4470
#         | SPACE |         | 4470
# the     | DET   |         | patient
# patient | NOUN  |         | referred
# was     | AUX   |         | referred
# referred| VERB  |         | referred
# after   | ADP   |         | was
# he      | PRON  |         | was
# was     | AUX   |         | referred
# hospital| NOUN  |         | was
# ...     | PUNCT |         | referred
#
#        | SPACE |         | ...
# 4473    | NUM   | CARDINAL| gentleman
#         | SPACE |         | 4473
# gentleman| PROPN |         | gentleman
# with    | ADP   |         | gentleman
# long    | ADJ   |         | history
# history | NOUN  |         | with
# of      | ADP   |         | history
# heroin  | NOUN  |         | abuse
# abuse   | NOUN  |         | tr
# tr      | ADP   |         | of
# ...     | PUNCT |         | gentleman
#
#        | SPACE |         | ...
# 4474    | NUM   | DATE    | cholesterol
#         | SPACE |         | 4474
# elevated| ADJ   |         | cholesterol
# cholesterol| NOUN  |         | cholesterol
# and     | CCONJ |         | cholesterol
# is      | AUX   |         | cholesterol
# on      | ADP   |         | is
# medication| NOUN  |         | on
# to      | ADP   |         | medication
# l       | NOUN  |         | to
# ...     | PUNCT |         | cholesterol
#
#        | SPACE |         | ...
# 4475    | NUM   | CARDINAL| patient
#         | SPACE |         | 4475
# patient | NOUN  |         | had
# had     | AUX   |         | had
# piece   | NOUN  |         | fall
# of      | ADP   |         | piece
# glass   | NOUN  |         | of
# fall    | NOUN  |         | had
# on      | ADP   |         | fall
# to      | ADP   |         | fall
# his     | DET   |         | righ
# righ    | NOUN  |         | to
# ...     | PUNCT |         | had
#
#        | SPACE |         | ...
# 4477    | NUM   | CARDINAL| palsy
#         | SPACE |         | 4477
# cerebral| ADJ   |         | palsy
# palsy   | ADJ   |         | palsy
# worsening| NOUN  |         | seizures
# seizures| NOUN  |         | seizures
# pleasant| ADJ   |         | yea
# yea     | NOUN  |         | seizures
# ...     | PUNCT |         | seizures
#
#        | SPACE |         | ...
# 4483    | NUM   | CARDINAL| consult
#                          | SPACE |         | 4483
# consult | NOUN  |         | consult
# for     | ADP   |         | consult
# prostate| NOUN  |         | cancer
# cancer  | NOUN  |         | for
#
#        | SPACE |         | cancer
# 4484    | NUM   | CARDINAL| patient
#         | SPACE |         | 4484
# patient | ADJ   |         | patient
# with    | ADP   |         | patient
# family  | NOUN  |         | history
# history | NOUN  |         | with
# of      | ADP   |         | history
# colon   | NOUN  |         | cancer
# cancer  | NOUN  |         | an
# an      | DET   |         | of
# ...     | PUNCT |         | patient
#
#        | SPACE |         | ...
# 4486    | NUM   |         | 4486
#               | SPACE |         | 4486
# the     | DET   |         | patient
# patient | NOUN  |         | needs
# needs   | VERB  |         | needs
# refills | NOUN  |         | needs
# on      | ADP   |         | refills
# her     | DET   |         | xanax
# xanax   | PROPN |         | on
#
#        | SPACE |         | xanax
# 4487    | NUM   | CARDINAL| patient
#         | SPACE |         | 4487
# patient | NOUN  |         | comes
# comes   | VERB  |         | comes
# for     | ADP   |         | comes
# discussion| NOUN  |         | for
# of      | ADP   |         | discussion
# screening| VERB  |         | of
# colo    | PROPN | GPE     | screening
# ...     | PUNCT |         | comes
#
#        | SPACE |         | ...
# 4489    | NUM   | DATE    | 4489
#         | SPACE |         | 4489
# year    | NOUN  |         | female
# old     | ADJ   |         | female
# female  | NOUN  |         | has
# whose   | DET   |         | sister
# year    | NOUN  | DATE    | sister
# old     | ADJ   |         | sister
# sister  | NOUN  |         | has
# has     | AUX   |         | has
# hist    | NOUN  |         | has
# ...     | PUNCT |         | has
#
#        | SPACE |         | ...
# 4490    | NUM   | CARDINAL| 4490
#         | SPACE |         | 4490
# the     | DET   |         | patient
# patient | NOUN  |         | admitted
# admitted| VERB  |         | admitted
# with    | ADP   |         | admitted
# palpitations| NOUN  |         | with
# and     | CCONJ |         | admitted
# pre     | VERB  |         | ...
# ...     | PUNCT |         | admitted
#
#        | SPACE |         | ...
# 4494    | NUM   | CARDINAL| hydronephrosis
#         | SPACE |         | 4494
# marked  | VERB  |         | hydronephrosis
# right   | ADJ   |         | hydronephrosis
# hydronephrosis| NOUN  |         | hydronephrosis
# without | ADP   |         | hydronephrosis
# hydruria| PROPN |         | without
#
#        | SPACE |         | hydruria
# 4495    | NUM   | CARDINAL| 4495
#         | SPACE |         | 4495
# the     | DET   |         | patient
# patient | NOUN  |         | had
# had     | AUX   |         | had
# several | ADJ   |         | episodes
# episodes| NOUN  |         | had
# where   | ADV   |         | fel
# she     | PRON  |         | fel
# fel     | VERB  | ORG     | episodes
# ...     | PUNCT |         | had
#
#        | SPACE |         | ...
# 4496    | NUM   | DATE    | patient
#         | SPACE |         | 4496
# patient | ADJ   |         | patient
# with    | ADP   |         | patient
# complaint| NOUN  |         | with
# of      | ADP   |         | complaint
# left    | ADJ   |         | patie
# knee    | NOUN  |         | pain
# pain    | NOUN  |         | patie
# patie   | NOUN  |         | of
# ...     | PUNCT |         | patient
#
#        | SPACE |         | ...
# 4497    | NUM   | CARDINAL| patient
#         | SPACE |         | 4497
# patient | ADJ   |         | patient
# with    | ADP   |         | patient
# mid     | ADJ   |         | son
# epigastric| ADJ   |         | pain
# abdominal| ADJ   |         | pain
# pain    | NOUN  |         | son
# son     | NOUN  |         | with
# ...     | PUNCT |         | patient
#
#        | SPACE |         | ...
# 4498    | NUM   | CARDINAL| patient
#         | SPACE |         | 4498
# patient | ADJ   |         | patient
# with    | ADP   |         | patient
# past    | ADJ   |         | history
# medical | ADJ   |         | history
# history | NOUN  |         | with
# of      | ADP   |         | history
# hypertens| NOUN  |         | of
# ...     | PUNCT |         | patient
#
#        | SPACE |         | ...
# 4505    | NUM   | DATE    | 4505
#         | SPACE |         | 4505
# the     | DET   |         | patient
# patient | NOUN  |         | suffering
# has     | AUX   |         | suffering
# been    | AUX   |         | suffering
# suffering| VERB  |         | suffering
# from    | ADP   |         | suffering
# intractabl| NOUN  |         | from
# ...     | PUNCT |         | suffering
#
#        | SPACE |         | ...
# 4507    | NUM   | DATE    | patient
#         | SPACE |         | 4507
# patient | ADJ   |         | patient
# with    | ADP   |         | patient
# history | NOUN  |         | with
# of      | ADP   |         | history
# right   | ADJ   |         | pons
# upper   | ADJ   |         | pons
# pons    | NOUN  |         | of
# and     | CCONJ |         | pons
# r       | NOUN  |         | pons
# ...     | PUNCT |         | patient
#
#        | SPACE |         | ...
# 4508    | NUM   | CARDINAL| 4508
#         | SPACE |         | 4508
# the     | DET   |         | patient
# patient | NOUN  |         | is
# is      | AUX   |         | is
# year    | NOUN  |         | old
# old     | ADJ   |         | female
# female  | NOUN  |         | is
# with    | ADP   |         | female
# invasive| ADJ   |         | d
# d       | NOUN  |         | with
# ...     | PUNCT |         | female
#
#        | SPACE |         | ...
# 4509    | NUM   | CARDINAL| patient
#         | SPACE |         | 4509
# patient | ADJ   |         | patient
# with    | ADP   |         | patient
# history | NOUN  |         | with
# of      | ADP   |         | history
# mesothelioma| NOUN  | GPE     | of
# and     | CCONJ |         | mesothelioma
# likel   | PROPN |         | mesothelioma
# ...     | PUNCT |         | patient
#
#        | SPACE |         | ...
# 4513    | NUM   | DATE    | 4513
#         | SPACE |         | 4513
# she     | PRON  |         | sent
# is      | AUX   |         | sent
# sent    | VERB  |         | sent
# for     | ADP   |         | sent
# evaluation| NOUN  |         | for
# of      | ADP   |         | evaluation
# ocular  | ADJ   |         | manifesta
# manifesta| NOUN  |         | of
# ...     | PUNCT |         | sent
#
#        | SPACE |         | ...
# 4516    | NUM   | CARDINAL| screening
#         | SPACE |         | 4516
# routine | ADJ   |         | screening
# ...
# bronchoscopy| PROPN |         | brushings
# brushings| NOUN  |         | washings
# washings| NOUN  |         | washings
# and     | CCONJ |         | washings
# biopsies| NOUN  |         | p
# p       | NOUN  |         | washings
# ...     | PUNCT |         | washings
#
#        | SPACE |         | ...
# 4936    | NUM   | CARDINAL| 4936
#         | SPACE |         | 4936
# bronchoscopy| ADJ   |         | bronchoscopy
# with    | ADP   |         | bronchoscopy
# bronchoalveolar| ADJ   |         | refra
# lavage  | NOUN  |         | refra
# refra   | VERB  |         | with
# ...     | PUNCT |         | bronchoscopy
#
#        | SPACE |         | ...
# 4937    | NUM   | CARDINAL| 4937
#         | SPACE |         | 4937
# diagnostic| ADJ   |         | bronchoscopy
# bronchoscopy| NOUN  |         | left
# and     | CCONJ |         | bronchoscopy
# limited | ADJ   |         | bronchoscopy
# left    | VERB  |         | left
# thora   | PROPN |         | left
# ...     | PUNCT |         | left
#
#        | SPACE |         | ...
# 4938    | NUM   | CARDINAL| body
#         | SPACE |         | 4938
# plastic | NOUN  |         | piece
# piece   | NOUN  |         | body
# foreign | ADJ   |         | body
# body    | NOUN  |         | body
# in      | ADP   |         | body
# the     | DET   |         | s
# right   | ADJ   |         | s
# main    | ADJ   |         | s
# s       | NOUN  |         | in
# ...     | PUNCT |         | body
#
#        | SPACE |         | ...
# 4939    | NUM   | DATE    | 4939
#         | SPACE |         | 4939
# bronchoscopy| PROPN |         | bronchoscopy
# for     | ADP   |         | bronchoscopy
# hypoxia | PROPN | GPE     | for
# and     | CCONJ |         | hypoxia
# increasing| VERB  |         | hypoxia
# pulmon  | NOUN  |         | bronchoscopy
# ...     | PUNCT |         | bronchoscopy
#
#        | SPACE |         | ...
# 4940    | NUM   | CARDINAL| bronchoscopy
#                   | SPACE |         | 4940
# diagnostic| ADJ   |         | bronchoscopy
# fiberoptic| ADJ   |         | bronchoscopy
# bronchoscopy| PROPN |         | bronchoscopy
#
#        | SPACE |         | bronchoscopy
# 4941    | NUM   | DATE    | 4941
#         | SPACE |         | 4941
# rigid   | ADJ   |         | removal
# bronchoscopy| ADJ   |         | removal
# removal | NOUN  |         | exc
# of      | ADP   |         | removal
# foreign | ADJ   |         | body
# body    | NOUN  |         | of
# exc     | PROPN |         | exc
# ...     | PUNCT |         | exc
#
#        | SPACE |         | ...
# 4942    | NUM   | CARDINAL| 4942
#         | SPACE |         | 4942
# bronchoscopy| ADV   |         | bronchoscopy
# with    | ADP   |         | bronchoscopy
# aspiration| NOUN  |         | with
# and     | CCONJ |         | bronchoscopy
# left    | VERB  |         | bronchoscopy
# upper   | ADJ   |         | lo
# lo      | PROPN |         | left
# ...     | PUNCT |         | bronchoscopy
#
#        | SPACE |         | ...
# 4943    | NUM   | CARDINAL| 4943
#         | SPACE |         | 4943
# bronchoscopy| ADJ   |         | bronchoscopy
# with    | ADP   |         | bronchoscopy
# brush   | NOUN  |         | biopsies
# biopsies| NOUN  |         | pn
# persistent| ADJ   |         | pn
# pn      | NOUN  |         | with
# ...     | PUNCT |         | bronchoscopy
#
#        | SPACE |         | ...
# 4944    | NUM   | DATE    | 4944
#         | SPACE |         | 4944
# bronchoscopy| ADV   |         | bronchoscopy
# for     | ADP   |         | bronchoscopy
# persistent| ADJ   |         | cough
# cough   | NOUN  |         | for
# productive| ADJ   |         | o
# o       | NOUN  |         | o
# ...     | PUNCT |         | o
#
#        | SPACE |         | ...
# 4945    | NUM   | DATE    | 4945
#         | SPACE |         | 4945
# fiberoptic| ADJ   |         | bronchoscopy
# bronchoscopy| NOUN  |         | bronchoscopy
# with    | ADP   |         | bronchoscopy
# endobronchial| ADJ   |         | bio
# bio     | NOUN  |         | with
# ...     | PUNCT |         | bronchoscopy
#
#        | SPACE |         | ...
# 4947    | NUM   | CARDINAL| atelectasis
#         | SPACE |         | 4947
# bronchoscopy| PROPN |         | atelectasis
# atelectasis| NOUN  |         | atelectasis
# and     | CCONJ |         | atelectasis
# mucous  | ADJ   |         | atelectasis
# plugging| NOUN  |         | atelectasis
#
#        | SPACE |         | plugging
# 4948    | NUM   | CARDINAL| evaluation
#         | SPACE |         | 4948
# evaluation| NOUN  |         | evaluation
# of      | ADP   |         | evaluation
# airway  | NOUN  |         | of
# for     | ADP   |         | evaluation
# possible| ADJ   |         | bacterial
# bacterial| ADJ   |         | for
# in      | ADP   |         | evaluation
# ...     | PUNCT |         | in
#
#        | SPACE |         | ...
# 4949    | NUM   | CARDINAL| 4949
#         | SPACE |         | 4949
# bronchiolitis| ADJ   |         | 4949
# respiratory| ADJ   |         | virus
# syncytial| ADJ   |         | virus
# virus   | NOUN  |         | bronchiolitis
# posi    | PROPN |         | posi
# ...     | PUNCT |         | posi
#
#        | SPACE |         | ...
# 4950    | NUM   | CARDINAL| 4950
#         | SPACE |         | 4950
# fiberoptic| ADJ   |         | bronchoscopy
# bronchoscopy| NOUN  |         | bronchoscopy
# for     | ADP   |         | bronchoscopy
# diagnosis| NOUN  |         | for
# of      | ADP   |         | diagnosis
# right   | NOUN  |         | of
# ...     | PUNCT |         | bronchoscopy
#
#        | SPACE |         | ...
# 4951    | NUM   | CARDINAL| 4951
#         | SPACE |         | 4951
# rigid   | ADJ   |         | bronchoscopy
# bronchoscopy| NOUN  |         | bronchoscopy
# with    | ADP   |         | bronchoscopy
# dilation| NOUN  |         | excision
# excision| NOUN  |         | with
# of      | ADP   |         | excision
# g       | NOUN  |         | of
# ...     | PUNCT |         | bronchoscopy
#
#        | SPACE |         | ...
# 4952    | NUM   | DATE    | angiogram
#         | SPACE |         | 4952
# bilateral| ADJ   |         | carotid
# carotid | PROPN |         | angiogram
# cerebral| PROPN |         | angiogram
# angiogram| PROPN |         | angiogram
# and     | CCONJ |         | angiogram
# right   | INTJ  |         | angiogram
# ...     | PUNCT |         | angiogram
#
#        | SPACE |         | ...
# 4953    | NUM   | DATE    | 4953
#         | SPACE |         | 4953
# bronchoscopy| PROPN |         | biopsies
# right   | ADJ   |         | biopsies
# upper   | PROPN |         | biopsies
# lobe    | PROPN |         | biopsies
# biopsies| NOUN  |         | biopsies
# and     | CCONJ |         | biopsies
# rig     | NOUN  |         | biopsies
# ...     | PUNCT |         | biopsies
#
#        | SPACE |         | ...
# 4956    | NUM   | CARDINAL| 4956
#         | SPACE |         | 4956
# critically| ADV   |         | ill
# ill     | ADJ   |         | year
# year    | NOUN  |         | old
# old     | ADJ   |         | old
# with    | ADP   |         | old
# multiple| ADJ   |         | medical
# medical | ADJ   |         | with
# ...     | PUNCT |         | old
#
#        | SPACE |         | ...
# 4958    | NUM   | CARDINAL| ash
#         | SPACE |         | 4958
# ash     | NOUN  |         | split
# split   | VERB  |         | split
# venous  | ADJ   |         | insertion
# port    | NOUN  |         | insertion
# insertion| NOUN  |         | split
# the     | DET   |         | ante
# right   | ADJ   |         | ante
# ante    | NOUN  |         | ante
# ...     | PUNCT |         | ante
#
#        | SPACE |         | ...
# 4959    | NUM   | CARDINAL| angiograms
#                            | SPACE |         | 4959
# carotid | PROPN |         | angiograms
# artery  | NOUN  |         | angiograms
# angiograms| PROPN |         | angiograms
#
#        | SPACE |         | angiograms
# 4960    | NUM   | DATE    | fibrillation
#         | SPACE |         | 4960
# atrial  | ADJ   |         | fibrillation
# fibrillation| NOUN  |         | angiograms
# with    | ADP   |         | fibrillation
# rapid   | ADJ   |         | res
# ventricular| ADJ   |         | res
# res     | NOUN  |         | with
# ...     | PUNCT |         | angiograms
#
#        | SPACE |         | ...
# 4961    | NUM   | DATE    | aortogram
#         | SPACE |         | 4961
# aortogram| PROPN |         | aortogram
# with    | ADP   |         | aortogram
# bilateral| ADJ   |         | extre
# segmental| NOUN  |         | extre
# lower   | ADJ   |         | extre
# extre   | PROPN |         | with
# ...     | PUNCT |         | aortogram
#
#        | SPACE |         | ...
# 4962    | NUM   | CARDINAL| replacement
#         | SPACE |         | 4962
# aortic  | ADJ   |         | replacement
# valve   | NOUN  |         | replacement
# replacement| NOUN  |         | replacement
# using   | VERB  |         | replacement
# mechanical| ADJ   |         | valv
# valv    | NOUN  |         | using
# ...     | PUNCT |         | replacement
#
#        | SPACE |         | ...
# 4963    | NUM   | CARDINAL| disease
#         | SPACE |         | 4963
# aortoiliac| PROPN |         | disease
# occlusive| ADJ   |         | disease
# disease | NOUN  |         | aortobifemoral
# aortobifemoral| ADJ   |         | aortobifemoral
# by      | ADV   |         | aortobifemoral
# ...     | PUNCT |         | aortobifemoral
#
#        | SPACE |         | ...
# 4964    | NUM   | CARDINAL| dementia
#         | SPACE |         | 4964
# dementia| PROPN |         | dementia
# and     | CCONJ |         | dementia
# aortoiliac| PROPN |         | bila
# occlusive| ADJ   |         | bila
# disease | NOUN  |         | bila
# bila    | PROPN |         | dementia
# ...     | PUNCT |         | dementia
#
#        | SPACE |         | ...
# 4966    | NUM   | CARDINAL| imaging
#         | SPACE |         | 4966
# arterial| ADJ   |         | imaging
# imaging | NOUN  |         | left
# of      | ADP   |         | imaging
# bilateral| ADJ   |         | extremities
# lower   | ADJ   |         | extremities
# extremities| NOUN  |         | of
#
#        | SPACE |         | extremities
# 4967    | NUM   | CARDINAL| imaging
#         | SPACE |         | 4967
# left    | VERB  |         | left
# heart   | NOUN  |         | cath
# cath    | PROPN |         | left
# selective| ADJ   |         | coronary
# coronary| PROPN |         | r
# angiogram| PROPN |         | r
# r       | NOUN  |         | left
# ...     | PUNCT |         | left
#
#        | SPACE |         | ...
# 4968    | NUM   | CARDINAL| angiography
#         | SPACE |         | 4968
# selective| ADJ   |         | angiography
# coronary| ADJ   |         | angiography
# angiography| NOUN  |         | angiography
# of      | ADP   |         | angiography
# the     | DET   |         | of
# right   | NOUN  |         | the
# co      | NOUN  |         | ...
# ...     | PUNCT |         | right
#
#        | SPACE |         | ...
# 4971    | NUM   | DATE    | note
#                                | SPACE |         | 4971
# sample  | NOUN  |         | note
# note    | NOUN  |         | note
# on      | ADP   |         | note
# angina  | PROPN |         | on
#
#        | SPACE |         | angina
# 4972    | NUM   | DATE    | adenosine
#         | SPACE |         | 4972
# adenosine| PROPN |         | angina
# with    | ADP   |         | note
# nuclear | ADJ   |         | scan
# scan    | NOUN  |         | with
# as      | SCONJ |         | scan
# the     | DET   |         | una
# patient | ADJ   |         | una
# una     | NOUN  |         | as
# ...     | PUNCT |         | note
#
#        | SPACE |         | ...
# 4975    | NUM   | CARDINAL| patient
#         | SPACE |         | 4975
# patient | NOUN  |         | had
# had     | AUX   |         | had
# markedly| ADV   |         | abnormal
# abnormal| ADJ   |         | test
# stress  | NOUN  |         | test
# test    | NOUN  |         | had
# with    | ADP   |         | test
# ...     | PUNCT |         | with
#
#        | SPACE |         | ...
# 4977    | NUM   | DATE    | gentleman
#         | SPACE |         | 4977
# gentleman| PROPN |         | gentleman
# with    | ADP   |         | gentleman
# long    | ADJ   |         | obesity
# standing| PROPN |         | obesity
# morbid  | NOUN  |         | obesity
# obesity | NOUN  |         | with
# re      | NOUN  |         | ...
# ...     | PUNCT |         | gentleman
#
#        | SPACE |         | ...
# 4978    | NUM   | CARDINAL| evaluation
#         | SPACE |         | 4978
# preop   | NOUN  |         | evaluation
# evaluation| NOUN  |         | evaluation
# regarding| VERB  |         | evaluation
# gastric | ADJ   |         | surgery
# bypass  | NOUN  |         | surgery
# surgery | NOUN  |         | regarding
#
#        | SPACE |         | surgery
# 4979    | NUM   | CARDINAL| patient
#         | SPACE |         | 4979
# patient | NOUN  |         | evaluation
# scheduled| VERB  |         | patient
# for     | ADP   |         | scheduled
# laparoscopic| PROPN |         | bypass
# gastric | PROPN |         | bypass
# bypass  | PROPN |         | for
#
#        | SPACE |         | bypass
# 4980    | NUM   | CARDINAL| bypass
#         | SPACE |         | 4980
# evaluation| NOUN  |         | evaluation
# for     | ADP   |         | evaluation
# elective| ADJ   |         | loss
# surgical| ADJ   |         | loss
# weight  | NOUN  |         | loss
# loss    | NOUN  |         | v
# v       | NOUN  |         | for
# ...     | PUNCT |         | evaluation
#
#        | SPACE |         | ...
# 4982    | NUM   | CARDINAL| evaluation
#                     | SPACE |         | 4982
# evaluation| NOUN  |         | evaluation
# for     | ADP   |         | evaluation
# bariatric| ADJ   |         | surgery
# surgery | NOUN  |         | for
#
#        | SPACE |         | surgery
# 4984    | NUM   | CARDINAL| patient
#         | SPACE |         | 4984
# patient | NOUN  |         | suffered
# suffered| VERB  |         | suffered
# from    | ADP   |         | suffered
# morbid  | NOUN  |         | obesity
# obesity | NOUN  |         | from
# for     | ADP   |         | suffered
# many    | ADJ   |         | for
# ...     | PUNCT |         | suffered
#
#        | SPACE |         | ...
# 4985    | NUM   | CARDINAL| patient
#         | SPACE |         | 4985
# patient | PROPN |         | presented
# presented| VERB  |         | presented
# to      | ADP   |         | presented
# the     | DET   |         | ser
# bariatric| ADJ   |         | ser
# surgery | NOUN  |         | ser
# ser     | NOUN  |         | to
# ...     | PUNCT |         | presented
#
#        | SPACE |         | ...
# 4989    | NUM   | CARDINAL| evaluation
#         | SPACE |         | 4989
# evaluation| NOUN  |         | evaluation
# for     | ADP   |         | evaluation
# elective| ADJ   |         | loss
# surgical| ADJ   |         | loss
# weight  | NOUN  |         | loss
# loss    | NOUN  |         | v
# v       | NOUN  |         | for
# ...     | PUNCT |         | evaluation
#
#        | SPACE |         | ...
# 4993    | NUM   | DATE    | environm
#         | SPACE |         | 4993
# chronic | PROPN |         | environm
# glossitis| PROPN |         | xerostomia
# xerostomia| PROPN |         | chronic
# probable| PROPN |         | environm
# environm| PROPN |         | environm
# ...     | PUNCT |         | environm
#
#        | SPACE |         | ...
# 4995    | NUM   | DATE    | 4995
#         | SPACE |         | 4995
# this    | DET   |         | is
# is      | AUX   |         | is
# month   | NOUN  | DATE    | old
# old     | ADJ   |         | caucasian
# baby    | NOUN  |         | boy
# boy     | NOUN  |         | caucasian
# caucasian| PROPN |         | is
# who     | PRON  |         | came
# came    | VERB  |         | caucasian
# ...     | PUNCT |         | is

# %% [markdown]
# # **STEP 16: Biomedical Name Entity Recognition (BIO-NER)**

# %% [markdown]
# For this task, we will apply Med7 model which is developed in the context of biomedical name entity recognition in terms of extracting significant information from the large number of medical dataset. The Med7 trained model comprises three components in its pipeline: <br>
#
#
# *   tagger
# *   parser
#
# *   clinical NER with seven categories

# %%
import spacy
import en_core_web_sm
nlp = en_core_web_sm.load()

# %% [markdown]
# **Test using dummy text**

# %%
def medicalNER_Exp2():
    
    col_dict={}
    seven_colours=['#e6194B', '#3cb44b', '#ffe119', '#ffd8b1', '#f58231', '#f032e6', '#42d4f4']
    for label, colour in zip(nlp.pipe_labels['ner'], seven_colours):
        col_dict[label]= colour
    options= {'ents': nlp.pipe_labels['ner'], 'colors':col_dict}  
    
    text='A patient was prescribed Magnesium hydroxide 400mg/5ml suspension PO of total 30ml bid for the next 5 days.'
    doc = nlp(text)
    spacy.displacy.render(doc, style='ent', jupyter=True, options=options)
    
    return [(ent.text, ent.label_) for ent in doc.ents]

# %%
medicalNER_Exp2()
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A patient was prescribed Magnesium hydroxide
# <mark class="entity" style="background: #e6194B; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     400mg/5ml
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  suspension PO of total
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30ml
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  bid for
# <mark class="entity" style="background: #3cb44b; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the next 5 days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</div></span>
# [('400mg/5ml', 'CARDINAL'), ('30ml', 'ORDINAL'), ('the next 5 days', 'DATE')]

# %% [markdown]
# The Med7 model identifies correctly all seven entities in the following example and highlights them in different colours for better visualisation:

# %% [markdown]
# **Test with original dataset**

# %% [markdown]
# First, we have to convert the dataframe into the from of string owing to the fact that it is quite difficult to feed the dataframe directly to the Med7 model instead of converting to the string format that I have experimented. Let's do that.

# %%
test_data2= NER_df['clean_desc'].to_string()

# %%
type(test_data2)
# Out:
# str

# %% [markdown]
# Observation: We have successfully converted our dataframe into the form of string format. Now let's apply the Med7 which is RoBERTa-base implementation. The authors of this model stated that their future works will improve its performance and introduce new feautres. Some entities may not be identified correctrly.

# %%
col_dict={}
seven_colours=['#e6194B', '#3cb44b', '#ffe119', '#ffd8b1', '#f58231', '#f032e6', '#42d4f4']
for label, colour in zip(nlp.pipe_labels['ner'], seven_colours):
  
  col_dict[label]= colour
  options= {'ents': nlp.pipe_labels['ner'], 'colors':col_dict}  
    
  #text='Objectives: The United Kingdom Parkinsons Disease Research Group (UKPDRG) trial found an increased mortality in patients with Parkinsons disease (PD) randomized to receive 10 mg selegiline per day and L-dopa compared with those taking L-dopa alone.'
  doc = nlp(test_data2)
  spacy.displacy.render(doc, style='ent', jupyter=True, options=options)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# **Observation: Look, we have applied the Med7 model to our dataset and it has roughly identified the entities. Some of them may not be correct and we have to measure the performance more, for this purpose, we need to experiment with a vast amount of dataset**

# %% [markdown]
# # **STEP 17: Abbreviation detection**

# %% [markdown]
# # **STEP 18: Negation with negspaCy**

# %% [markdown]
# # **STEP 19: Keywords Extraction**

# %%
NER_df.head(3)
# Out:
#                                          description  \
# 0   A 23-year-old white female presents with comp...
# 1           Consult for laparoscopic gastric bypass.
# 2           Consult for laparoscopic gastric bypass.
#
#                                        transcription  \
# 0  SUBJECTIVE:,  This 23-year-old white female pr...
# 1  PAST MEDICAL HISTORY:, He has difficulty climb...
# 2  HISTORY OF PRESENT ILLNESS: , I have seen ABC ...
#
#                                             keywords  \
# 0  allergy / immunology, allergic rhinitis, aller...
# 1  bariatrics, laparoscopic gastric bypass, weigh...
# 2  bariatrics, laparoscopic gastric bypass, heart...
#
#                                           clean_desc  \
# 0  year old white female presents with complaint ...
# 1            consult for laparoscopic gastric bypass
# 2            consult for laparoscopic gastric bypass
#
#                                            NER_token  \
# 0  [year, old, white, female, presents, with, com...
# 1      [consult, for, laparoscopic, gastric, bypass]
# 2      [consult, for, laparoscopic, gastric, bypass]
#
#                                   NER_token_filtered  \
# 0  [year, old, white, female, presents, complaint...
# 1           [consult, laparoscopic, gastric, bypass]
# 2           [consult, laparoscopic, gastric, bypass]
#
#                                       NER_stemmed  \
# 0  year old white femal present complaint allergi
# 1               consult laparoscop gastric bypass
# 2               consult laparoscop gastric bypass
#
#                                     NER_lemmatized
# 0  year old white female present complaint allergy
# 1              consult laparoscopic gastric bypass
# 2              consult laparoscopic gastric bypass

# %%
pip install keybert
# Out:
# Collecting keybert
#   Downloading keybert-0.5.1.tar.gz (19 kB)
# Collecting sentence-transformers>=0.3.8
#   Downloading sentence-transformers-2.2.0.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 3.3 MB/s
# Requirement already satisfied: scikit-learn>=0.22.2 in /usr/local/lib/python3.7/dist-packages (from keybert) (1.0.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.7/dist-packages (from keybert) (1.21.6)
# Collecting rich>=10.4.0
#   Downloading rich-12.3.0-py3-none-any.whl (232 kB)
#      |████████████████████████████████| 232 kB 10.4 MB/s
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from rich>=10.4.0->keybert) (2.6.1)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from rich>=10.4.0->keybert) (4.2.0)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 6.1 MB/s
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.2->keybert) (3.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.2->keybert) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.2->keybert) (1.1.0)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 40.4 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.3.8->keybert) (4.64.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.3.8->keybert) (1.11.0+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.12.0+cu113)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.3.8->keybert) (3.2.5)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 39.4 MB/s
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.5.1-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 6.4 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (3.6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2019.12.20)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (21.3)
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      |████████████████████████████████| 880 kB 38.8 MB/s
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 36.1 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (4.11.3)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 39.5 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (3.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (3.8.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers>=0.3.8->keybert) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2.10)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (7.1.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers>=0.3.8->keybert) (7.1.2)
# Building wheels for collected packages: keybert, sentence-transformers, sacremoses
#   Building wheel for keybert (setup.py) ... done
#   Created wheel for keybert: filename=keybert-0.5.1-py3-none-any.whl size=21332 sha256=69f226f8bba50f5632b5fc136ea81eeae74ca9f18ba3968240a58f25ac9f3225
#   Stored in directory: /root/.cache/pip/wheels/8e/95/c5/f5ceed2a9f9e80bc1a706a10a6fb03d726df7a3dd11800a58b
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.0-py3-none-any.whl size=120747 sha256=d9de0c64729ff78488fc77061e734fb2b999350a0bc5870dfb41988ef15f889e
#   Stored in directory: /root/.cache/pip/wheels/83/c0/df/b6873ab7aac3f2465aa9144b6b4c41c4391cfecc027c8b07e7
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=130f4ff200d8a3b8758d5143ffa6512b030e3fddf7a974e641907139ebd07dab
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built keybert sentence-transformers sacremoses
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers, sentencepiece, commonmark, sentence-transformers, rich, keybert
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed commonmark-0.9.1 huggingface-hub-0.5.1 keybert-0.5.1 pyyaml-6.0 rich-12.3.0 sacremoses-0.0.53 sentence-transformers-2.2.0 sentencepiece-0.1.96 tokenizers-0.12.1 transformers-4.18.0

# %%
from keybert import KeyBERT

# %%
test_data3= NER_df['clean_desc'].to_string()

# %%
kw_model= KeyBERT()
keywords= kw_model.extract_keywords(test_data3)
keywords
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# [('laparoscopic', 0.3729),
#  ('tracheostomy', 0.3698),
#  ('postoperative', 0.3672),
#  ('laparotomy', 0.3635),
#  ('metastasectomy', 0.3621)]

# %% [markdown]
# keyphrase_ngram_range to set the length of the resulting keywords/keyphrases

# %%
kw_model.extract_keywords(test_data3, keyphrase_ngram_range=(1,1), stop_words=None)
# Out:
# [('laparoscopic', 0.3729),
#  ('tracheostomy', 0.3698),
#  ('postoperative', 0.3672),
#  ('laparotomy', 0.3635),
#  ('metastasectomy', 0.3621)]

# %% [markdown]
# To extract keyphrases, simply set keyphrase_ngram_range to (1, 2) or higher depending on the number of words

# %%
kw_model.extract_keywords(test_data3, keyphrase_ngram_range=(1,2), stop_words=None)
# Out:
# [('bariatric surgery', 0.4977),
#  ('tracheostomy urgent', 0.4891),
#  ('diagnostic operative', 0.4772),
#  ('laparoscopic roux', 0.472),
#  ('laparoscopic supracervical', 0.4644)]

# %% [markdown]
# We can highlight the keywords in the document by simply setting hightlight:

# %%
keywords = kw_model.extract_keywords(test_data3, highlight=True)
# Out:
# 0 year old white female presents with complaint ... 1 consult for laparoscopic gastric bypass
# 2 consult for laparoscopic gastric bypass 3 mode doppler 4 echocardiogram 5 morbid obesity
# laparoscopic antecolic antegast... 6 liposuction of the supraumbilical abdomen revi... 7
# echocardiogram 8 suction assisted lipectomy lipodystrophy of th... 9 echocardiogram and
# doppler 10 morbid obesity laparoscopic roux en gastric by... 11 normal left ventricle
# moderate biatrial enlarg... 13 patient presented to the bariatric surgery ser... 14 surgical
# right eye insertion of radioacti... 403 radical retropubic prostatectomy robotic assis... 404
# open radical retropubic prostatectomy with bil... 405 radical retropubic nerve sparing
# prostatectomy... 406 radical retropubic prostatectomy with pelvic l... 408 insertion of port
# catheter via the left subcla... 409 right pterional craniotomy with obliteration o... 410
# insertion of port cath via left subclavian vei... 411 insertion of subclavian dual port port
# cath an... 412 right subclavian port cath insertion in patien... 413 bleeding after transanal
# excision five days ag... 414 the patient with left completion hemithyroidec... 415 placement
# of port cath under fluoroscopic guid... 416 port insertion through the right subclavian ve...
# 417 port cath insertion template catheter was inse... 418 transnasal transsphenoidal approach
# in resecti... 419 application of pmt large halo crown and vest c... 420 ultrasound guided
# right pleurocentesis for rig... 421 closed reduction and pinning of the right ulna... 422
# plantar fascitis left foot partial plantar fas... 423 chest tube talc pleurodesis of the
# right chest 424 endoscopic assisted transsphenoidal exploratio... 425 year old pound male
# presents with extreme pain... 426 external fixation of left pilon fracture and c... 427
# pilonidal cyst with abscess formation excision... 428 revision and in situ pinning of the
# right hip 429 left hemothorax rule out empyema insertion of ... 430 botulinum toxin injection
# bilateral rectus fem... 431 phenol neurolysis left musculocutaneous nerve ... 432 right
# phacoemulsification of cataract with int... 433 phenol neurolysis right obturator nerve
# botuli... 434 cataract right eye phacoemulsification of cata... 435 picc line insertion 436
# phacoemulsification with posterior chamber int... 437 phacoemulsification of cataract
# extraocular le... 438 phacoemulsification with posterior chamber int... 439 amputation distal
# phalanx and partial proximal... 440 phacoemulsification with iol right eye catarac... 441
# phacoemulsification of cataract and posterior ... 442 cataract right eye phacoemulsification
# with in... 443 cataract extraction with phacoemulsification a... 444 phacoemulsification with
# intraocular lens plac... 445 cataract right eye phacoemulsification with in... 446 cataract
# extraction via phacoemulsification wi... 447 visually significant nuclear sclerotic
# catarac... 448 cataract right eye phacoemulsification with in... 449 visually significant
# cataract left eye phacoem... 450 cataract nuclear sclerotic right eye phacoemul... 451
# phacoemulsification and extracapsular cataract... 452 perlane injection for the nasolabial
# fold rest... 453 ex plantation of inflatable penile prosthesis ... 454 year old young lady is
# in the renal failure an... 455 permacath placement renal failure 456 phacoemulsification with
# posterior chamber int... 457 nuclear sclerotic cataract right eye kelman ph... 458 excision
# of penile skin bridges about cm in size 460 pelvic laparotomy lysis of pelvic adhesions an...
# 461 percutaneous endoscopic gastrostomy tube prote... 463 open repair of right pectoralis
# major tendon r... 464 ligation clip interruption of patent ductus ar... 465 sinus bradycardia
# sick sinus syndrome poor thr... 466 coil embolization of patent ductus arteriosus 467
# patellar tendon and medial and lateral retinac... 468 excision of right superior parathyroid
# adenoma... 469 paracentesis large abdominal mass which was cy... 470 ultrasound guided
# paracentesis for ascites 471 reduction of paraphimosis 473 insertion of transvenous pacemaker
# for tachybr... 474 pacemaker icd interrogation severe nonischemic... 476 single chamber
# pacemaker implantation successf... 477 implantation of dual chamber permanent pacemaker 479
# plantar flex third metatarsal and talus bunion... 480 open reduction and internal fixation of
# left d... 481 ossatron extracorporeal shockwave therapy to r... 482 open reduction and
# internal fixation orif of t... 483 acetabular fracture on the left posterior colu... 484 open
# reduction and internal fixation of the le... 485 distal metaphyseal osteotomy and
# bunionectomy ... 486 open reduction and internal fixation of left a... 488 open reduction and
# internal fixation orif of c... 489 fractured right fifth metatarsal open reductio... 490 open
# reduction and internal fixation of left l... 491 open left angle comminuted angle of mandible
# a... 492 open reduction and internal fixation of left t... 493 hawkins iv talus fracture open
# reduction inter... 494 orchiopexy inguinal herniorrhaphy 495 open reduction and internal
# fixation of right ... 496 bilateral orchiopexy this year old boy has bee... 497 open
# reduction and internal fixation high grad... 499 right orchiopexy and right inguinal hernia
# repair 500 left inguinal hernia repair left orchiopexy wi... 501 right undescended testicle
# orchiopexy herniorr... 502 left facial cellulitis and possible odontogeni... 503 examination
# under anesthesia diagnostic laparo... 504 leukemic meningitis right frontal side inlet o...
# 505 left orchiopexy ectopic left testis the patien... 506 bilateral scrotal orchiectomy 507
# incision and drainage and excision of the olec... 508 chronic plantar fasciitis right foot
# open plan... 509 acute acalculous cholecystitis open cholecyste... 510 nissen fundoplication
# cm midline incision was ... 511 nipple areolar reconstruction utilizing full t... 512 right
# radical nephrectomy and assisted laparos... 513 transplant nephrectomy after rejection of
# rena... 514 left transforaminal neuroplasty with nerve roo... 515 repair of nerve and tendon
# right ring finger a... 516 laparoscopic right partial nephrectomy due to ... 517 laparoscopic
# right radical nephrectomy due to ... 518 excision of neuroma third interspace left foot...
# 519 needle localized excisional biopsy left breast... 520 stage and ii neuromodulator 521
# needle localized excisional biopsy of the left... 522 left partial nephrectomy due to left
# renal mass 523 left laparoscopic hand assisted nephrectomy 524 malignant mass of the left
# neck squamous cell ... 525 nasal septoplasty bilateral submucous resectio... 527 left neck
# dissection metastatic papillary canc... 528 nonpalpable neoplasm right breast needle local...
# 529 nasal septal reconstruction bilateral submucou... 530 bilateral nasolacrimal probing
# tearing eyelash... 531 bilateral myringotomies with insertion of sant... 532 open reduction
# nasal fracture with nasal septo... 533 bilateral myringotomies and insertion of shepa... 535
# multiple stent placements with impella circula... 536 bilateral myringotomies insertion of pe
# tubes ... 537 mohs micrographic surgery for basal cell ca at... 538 mitral valve repair using
# quadrangular resecti... 539 mohs micrographic surgery for basal cell ca at... 540 arthroscopy
# with arthroscopic rotator cuff deb... 541 endoscopic subperiosteal midface lift using th...
# 542 right middle ear exploration with goldenberg t... 543 mini laparotomy radical retropubic
# prostatecto... 544 biopsy proven mesothelioma placement of port c... 545 rhabdomyosarcoma of
# the left orbit left subcla... 546 right nodular malignant mesothelioma 547 microsuspension
# direct laryngoscopy with biops... 548 central neck reoperation with removal of resid... 549
# arthroscopy medial meniscoplasty lateral menis... 550 right pleural effusion and suspected
# malignant... 551 left metastasectomy of metastatic renal cell c... 552 posterior mediastinal
# mass with possible neura... 553 the patient had undergone mitral valve repair ... 554
# mediastinal exploration and delayed primary ch... 555 medial branch rhizotomy lumbosacral
# fluoroscop... 556 excision of soft tissue mass right foot the pa... 557 an example template
# for meatotomy 558 closed reduction of mandible fractures with er... 559 bilateral reduction
# ct gui... 951 cystopyelogram clot evacuation transurethral r... 952 laparoscopic assisted
# vaginal hysterectomy bil... 953 endoscopic and microsurgical transnasal resect... 954 ct
# guided needle placement ct guided biopsy of... 955 right frontotemporal craniotomy and
# evacuation... 956 left temporal craniotomy and removal of brain ... 957 acute left subdural
# hematoma left frontal temp... 958 bilateral orbital frontal zygomatic craniotomy... 959 left
# retrosigmoid craniotomy and excision of a... 960 occipital craniotomy removal of large tumor
# us... 961 biparietal craniotomy insertion of left latera... 962 cystoscopy cryosurgical
# ablation of the prostate 963 right frontal craniotomy with resection of rig... 964 right
# sided craniotomy for evacuation of right... 965 right burr hole craniotomy for evacuation of
# s... 966 anterior cranial vault reconstruction with fro... 967 selective coronary angiography
# placement of ov... 968 postoperative hemorrhage examination under ane... 969 lateral and
# plantar condylectomy fifth left me... 970 selective coronary angiography left heart cath...
# 971 cauterization of peri and intra anal condyloma... 972 cervical cone biopsy dilatation
# curettage 973 colonoscopy with random biopsies and culture 974 colpocleisis and rectocele
# repair 975 completion thyroidectomy with limited right pa... 976 colonoscopy with photos the
# patient is an year... 978 woman referred for colonoscopy secondary to he... 979 small
# internal hemorrhoids and ileal colonic a... 980 the patient with recent change in bowel
# functi... 981 colonoscopy with multiple biopsies including t... 982 total colonoscopy with
# biopsy and snare polype... 986 common description of colonoscopy 988 colonoscopy conscious
# ...
# 4567 evaluation for elective surgical weight loss v... 4568 acute renal failure probable
# renal vein thromb... 4574 possible exposure to ant bait she is not exhib... 4582
# comprehensive annual health maintenance examin... 4584 the patient is year old female who
# presents to... 4586 acute episode of agitation she was complaining... 4588 patient had
# markedly abnormal stress test with... 4589 acne from continually washing area frequent ph...
# 4590 patient status post gastric bypass surgery dev... 4593 the patient was referred due to
# concerns regar... 4600 consultation for left foot pain 4603 consultation for wrist pain 4604
# mri report cervical spine chiropractic specific 4605 pain management for post laminectomy low
# back ... 4611 insertion of vvir permanent pacemaker this is ... 4613 right and left carotid
# ultrasound 4614 need for intravenous access insertion of right... 4616 the patient was
# exercised according to standar... 4617 coronary artery bypass surgery and aortic sten... 4618
# bilateral carotid ultrasound to evaluate pain 4619 insertion of right brachial artery
# arterial ca... 4620 urgent cardiac catheterization with coronary a... 4621 transesophageal
# echocardiographic examination ... 4622 transesophageal echocardiogram woman admitted ... 4623
# transesophageal echocardiogram the transesopha... 4624 transesophageal echocardiogram mrsa
# bacteremia... 4625 transesophageal echocardiogram due to vegetati... 4626 insertion of
# transesophageal echocardiography ... 4627 tracheostomy change shiley with proximal exten...
# 4628 tracheostomy with skin flaps and scoop procedu... 4630 tilt table test patient with past
# medical hist... 4632 tracheotomy for patient with respiratory failure 4633 transesophageal
# echocardiogram for aortic sten... 4634 aortic stenosis insertion of toronto stentless... 4635
# thrombosed left forearm loop fistula graft chr... 4636 thromboendarterectomy of right common
# external... 4637 thrombectomy av shunt left forearm and patch a... 4638 left muscle sparing
# mini thoracotomy with left... 4639 left thoracotomy with total pulmonary decortic... 4640
# tilt table test tilt table test is negative fo... 4641 empyema right thoracotomy total
# decortication ... 4642 left thoracotomy with drainage of pleural flui... 4643 left
# thoracoscopy and left thoracotomy with de... 4644 mm dacron graft replacement of type
# thoracoabd... 4645 left mesothelioma focal left anterior pleural ... 4646 the patient was
# originally hospitalized second... 4647 insertion of right internal jugular tessio cat... 4648
# thoracentesis left pleural effusion left hemot... 4650 thoracentesis left malignant pleural
# effusion ... 4651 insertion of left subclavian tesio hemodialysi... 4653 the patient is month
# old who presented with su... 4654 subxiphoid pericardiotomy symptomatic pericard... 4655
# emergent subxiphoid pericardial window transes... 4656 chest pain chest wall tenderness
# occurred with... 4657 insertion of right subclavian central venous c... 4658 dobutrex stress
# test for abnormal ekg 4659 thallium stress test for chest pain 4660 chest pain hypertension
# stress test negative f... 4661 subxiphoid pericardial window blade scalpel wa... 4662 stress
# test adenosine myoview ischemic cardiom... 4663 dobutamine stress test for atrial
# fibrillation 4667 the patient is admitted for shortness of breat... 4668 chest single view
# post op for asd atrial septa... 4669 pulmonary disorder with lung mass pleural effu... 4670
# insertion of shiley tracheostomy tube blade sc... 4671 repair of total anomalous pulmonary
# venous con... 4672 the patient was admitted approximately days ag... 4673 ligation and
# stripping of left greater sapheno... 4675 selective coronary angiography coronary angiop...
# 4676 elevated cardiac enzymes fullness in chest abn... 4678 pulmonary function test mild
# restrictive airfl... 4679 year old male with fever endocarditis 4680 pulmonary valve stenosis
# supple pulmonic narro... 4681 increasing oxygen requirement baby boy has sig... 4682 patient
# returns to pulmonary medicine clinic f... 4683 sample of pulmonary function test 4686
# pulmonary function test in patient with smokin... 4687 sample of pulmonary function test 4688
# pulmonary function test mild to moderate obstr... 4690 patient with complaints of significant
# coughin... 4691 pulmonary function test to evaluate dyspnea 4693 port cath insertion template
# catheter was inse... 4694 pulmonary medicine clinic for followup evaluat... 4696 insertion of
# subclavian dual port port cath an... 4699 atypical pneumonia hypoxia rheumatoid arthriti...
# 4700 consult for subcutaneous emphysema and small r... 4702 left hemothorax rule out empyema
# insertion of ... 4703 chest tube talc pleurodesis of the right chest 4704 ultrasound guided
# right pleurocentesis for rig... 4706 coil embolization of patent ductus arteriosus 4707 six
# month follow up visit for paroxysmal atria... 4709 ligation clip interruption of patent
# ductus ar... 4710 picc line insertion 4712 sinus bradycardia sick sinus syndrome poor thr...
# 4713 nuclear cardiac stress report recurrent angina... 4715 insertion of transvenous
# pacemaker for tachybr... 4718 pacemaker icd interrogation severe nonischemic... 4719 single
# chamber pacemaker implantation successf... 4721 implantation of dual chamber permanent
# pacemaker 4722 myocardial perfusion imaging patient with hist... 4723 myocardial perfusion
# imaging patient had previ... 4724 myocardial perfusion study at rest and stress ... 4725
# multiple stent placements with impella circula... 4726 resting myoview perfusion scan and
# gated myoca... 4727 mri right parietal metastatic adenocarcinoma l... 4730 loculated left
# effusion multilobar pneumonia p... 4731 mitral valve repair using quadrangular resecti...
# 4732 suspension microlaryngoscopy rigid bronchoscop... 4733 right pleural effusion and
# suspected malignant... 4735 posterior mediastinal mass with possible neura... 4736 myoview
# the patient was admitted after undergoing draw... 4829 dobutamine stress test for chest pain
# as the p... 4830 patient had some cold symptoms was treated as ... 4836 direct laryngoscopy
# and bronchoscopy 4837 the patient is year old female who was treated... 4839 ct of chest with
# contrast abnormal chest ray d... 4840 cerebrovascular accident cva with right arm we... 4842
# chest pain shortness of breath and cough evalu... 4843 shortness of breath for two weeks and
# history ... 4844 year old white male with recently diagnosed ad... 4845 coronary artery cta
# with calcium scoring and c... 4846 ccta with cardiac function calcium scoring 4847 ct chest
# with contrast 4848 selective coronary angiography left heart cath... 4849 acute on chronic
# copd exacerbation and communi... 4850 common ct chest template 4852 chronic obstructive
# pulmonary disease copd exa... 4853 selective coronary angiography placement of ov... 4854
# year old male with copd and history of broncho... 4855 ccta with cardiac function and calcium
# scoring 4856 the patient admitted with palpitations and pre... 4862 left and right coronary
# system cineangiography... 4863 juxtaductal coarctation of the aorta dilated c... 4865 left
# and right coronary system cineangiography... 4866 left pleural effusion parapneumonic
# loculated ... 4868 resection of left chest wall tumor partial res... 4869 bilateral pleural
# effusion removal of bilatera... 4870 postcontrast ct chest pulmonary embolism proto... 4871
# lady was admitted to the hospital with chest p... 4872 chest tube insertion done by two
# physicians in... 4873 chest pa lateral to evaluate shortness of brea... 4874 patient with
# family history of premature coron... 4876 delayed primary chest closure open chest statu...
# 4877 right hemothorax insertion of french chest tub... 4878 chest pain possible syncopal
# spells she has be... 4879 carotid ultrasonic color flow imaging 4880 left carotid
# endarterectomy with endovascular ... 4881 right subclavian triple lumen central line pla...
# 4882 carotid and cerebral arteriogram abnormal caro... 4883 insertion of central venous line
# and arterial ... 4884 central line insertion empyema thoracis and ne... 4885 right common
# carotid endarterectomy internal c... 4886 right carotid stenosis and prior cerebrovascul...
# 4887 direct current cardioversion this is year old ... 4888 direct current cardioversion
# successful direct... 4890 problem of essential hypertension symptoms tha... 4891
# cardioversion unsuccessful direct current card... 4892 male with history of therapy
# controlled hypert... 4893 cardiology office visit sample note 4894 congestive heart failure
# due to rapid atrial f... 4895 cardioversion an year old woman with history o... 4896 patient
# with chest pains cad and cardiomyopathy 4897 follow up update on patient with left carotid
# ... 4899 year old man with respiratory distress history... 4900 cardiolite treadmill exercise
# stress test the ... 4912 left heart cardiac catheterization 4915 percutaneous intervention
# with drug eluting st... 4916 left heart catheterization with coronary angio... 4917 cardiac
# catheterization coronary artery diseas... 4918 left heart catheterization chest pain
# coronary... 4919 left heart catheterization lv cineangiography ... 4921 left cardiac
# catheterization with selective ri... 4922 orthostatic cardiac allograft transplantation ...
# 4923 cardiac catheterization an obese female with f... 4924 the patient with atypical type
# right arm disco... 4925 white male with onset of chest pain with histo... 4926 redo coronary
# bypass grafting right and left i... 4927 he is year old man who suffers from chronic an...
# 4928 coronary artery bypass grafting cabg progressi... 4929 patient with significant angina
# with moderate ... 4930 coronary artery bypass grafting cabg left inte... 4931 coronary artery
# bypass grafting times three ut... 4932 coronary bypass graft utilizing left internal ... 4933
# lumbar osteomyelitis and need for durable cent... 4934 flexible bronchoscopy pediatric 4935
# bronchoscopy brushings washings and biopsies p... 4936 bronchoscopy with bronchoalveolar
# lavage refra... 4937 diagnostic bronchoscopy and limited left thora... 4938 plastic piece
# foreign body in the right main s... 4939 bronchoscopy for hypoxia and increasing pulmon...
# 4940 diagnostic fiberoptic bronchoscopy 4941 rigid bronchoscopy removal of foreign body
# exc... 4942 bronchoscopy with aspiration and left upper lo... 4943 bronchoscopy with brush
# biopsies persistent pn... 4944 bronchoscopy for persistent cough productive o... 4945
# fiberoptic bronchoscopy with endobronchial bio... 4947 bronchoscopy atelectasis and mucous
# plugging 4948 evaluation of airway for possible bacterial in... 4949 bronchiolitis
# respiratory syncytial virus posi... 4950 fiberoptic bronchoscopy for diagnosis of right...
# 4951 rigid bronchoscopy with dilation excision of g... 4952 bilateral carotid cerebral
# angiogram and right... 4953 bronchoscopy right upper lobe biopsies and rig... 4956 critically
# ill year old with multiple medical ... 4958 ash split venous port insertion the right ante...
# 4959 carotid artery angiograms 4960 atrial fibrillation with rapid ventricular res... 4961
# aortogram with bilateral segmental lower extre... 4962 aortic valve replacement using
# mechanical valv... 4963 aortoiliac occlusive disease aortobifemoral by... 4964 dementia and
# aortoiliac occlusive disease bila... 4966 arterial imaging of bilateral lower extremities
# 4967 left heart cath selective coronary angiogram r... 4968 selective coronary angiography of
# the right co... 4971 sample note on angina 4972 adenosine with nuclear scan as the patient
# una... 4975 patient had markedly abnormal stress test with... 4977 gentleman with long
# standing morbid obesity re... 4978 preop evaluation regarding gastric bypass surgery 4979
# patient scheduled for laparoscopic gastric bypass 4980 evaluation for elective surgical
# weight loss v... 4982 evaluation for bariatric surgery 4984 patient suffered from morbid
# obesity for many ... 4985 patient presented to the bariatric surgery ser... 4989 evaluation
# for elective surgical weight loss v... 4993 chronic glossitis xerostomia probable environm...
# 4995 this is month old baby boy caucasian who came ...

# %% [markdown]
# **Max sum similarity**

# %%
kw_model.extract_keywords(test_data3, keyphrase_ngram_range=(3, 3), stop_words='english',
                              use_maxsum=True, nr_candidates=20, top_n=5)
# Out:
# [('218 transurethral resection', 0.4689),
#  ('620 laparoscopic supracervical', 0.4705),
#  ('post gastric bypass', 0.4726),
#  ('exploration tracheostomy urgent', 0.473),
#  ('patient presented bariatric', 0.4839)]

# %% [markdown]
# **Maximal Marginal Relevance**

# %%
kw_model.extract_keywords(test_data3, keyphrase_ngram_range=(3, 3), stop_words='english',
                              use_mmr=True, diversity=0.7)
# Out:
# [('evaluation bariatric surgery', 0.5359),
#  ('ph 2481 normal', 0.1078),
#  ('cervical epidural steroid', 0.2255),
#  ('creation autologous right', 0.0712),
#  ('bypass mode doppler', 0.1128)]

# %%
kw_model.extract_keywords(test_data3, keyphrase_ngram_range=(3, 3), stop_words='english',use_mmr=True, diversity=0.2)
# Out:
# [('evaluation bariatric surgery', 0.5359),
#  ('exploration tracheostomy urgent', 0.473),
#  ('2590 laparoscopic supracervical', 0.4855),
#  ('obesity laparoscopic roux', 0.505),
#  ('gastric bypass consult', 0.4998)]
